# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_absolute_error, mean_squared_error
import random

# 设置随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# 在代码的开头设置随机种子
set_seed(42)

# 读取数据
data = pd.read_csv('final_50_all.csv')

num_features = ['temperature_2m (°C)', 'apparent_temperature (°C)', 'rain (mm)', 'wind_speed_100m (km/h)']

# 特征工程
data['hour'] = pd.to_datetime(data['hour'])
data['year'] = data['hour'].dt.year
data['month'] = data['hour'].dt.month
data['day'] = data['hour'].dt.day
data['hour_of_day'] = data['hour'].dt.hour
data['weekday'] = data['hour'].dt.weekday

data['hour_sin'] = np.sin(2 * np.pi * data['hour_of_day'] / 24)
data['hour_cos'] = np.cos(2 * np.pi * data['hour_of_day'] / 24)
data['weekday_sin'] = np.sin(2 * np.pi * data['weekday'] / 7)
data['weekday_cos'] = np.cos(2 * np.pi * data['weekday'] / 7)
data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

# 数值特征缩放
scaler = MinMaxScaler()
data[num_features] = scaler.fit_transform(data[num_features])

data.drop(['month','day','hour', 'hour_of_day', 'weekday'], axis=1, inplace=True)

# 提取最终特征和目标
features = num_features + ['hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos','month_sin','month_cos'] 
target = 'ride_count'

X = data[features].values
y = data[target].values

def create_sequences(data, target, sequence_length):
    """
    将时间序列数据转换为带有输入序列和目标值的形式
    """
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(target[i + sequence_length])
    return np.array(X), np.array(y)

# 设置序列长度
sequence_length = 24  # 例如使用过去24小时的数据预测
X, y = create_sequences(X, y, sequence_length)

# K折交叉验证（5折）
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold = 0

train_losses = []
val_losses = []
maes = []
rmses = []

for train_index, val_index in kf.split(X):
    fold += 1
    print(f"Fold {fold}/{5}")
    
    # 划分训练集和验证集
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # 转换为张量
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

    # 数据加载器
    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=32)
    
    # 定义GRU模型
    class GRUModel(nn.Module):
        def __init__(self, input_size, hidden_size, output_size, dropout, cnn_channels, kernel_size):
            super(GRUModel, self).__init__()
            # 添加 CNN 层
            self.conv1d = nn.Conv1d(in_channels=input_size, out_channels=cnn_channels, kernel_size=kernel_size, padding=kernel_size // 2)
            self.relu = nn.ReLU()

            # GRU 层
            self.gru = nn.GRU(cnn_channels, hidden_size, batch_first=True)
            
            # 全连接层
            self.fc = nn.Linear(hidden_size, output_size)
            self.dropout = nn.Dropout(dropout)
        
        def forward(self, x):
            # CNN 层
            x = x.permute(0, 2, 1)  # 为 Conv1d 调整形状
            x = self.conv1d(x)  # 通过 1D 卷积层
            x = self.relu(x)    # 激活函数
            x = x.permute(0, 2, 1)  # 调整形状回 [batch_size, seq_length, cnn_channels]

            # GRU 层
            out, _ = self.gru(x)  # [batch_size, seq_length, hidden_size]

            # Dropout 和全连接层
            out = self.dropout(out[:, -1, :])  # 取最后一个时间步的输出
            out = self.fc(out)  # 全连接层
            return out

    # 模型参数
    input_size = len(features)  # 输入特征数
    hidden_size = 64           # 隐藏层大小
    output_size = 1            # 输出大小（预测目标变量）
    dropout = 0.2              # Dropout 概率
    cnn_channels = 32         # CNN 输出通道数
    kernel_size = 3            # CNN 卷积核大小

    # 实例化模型
    model = GRUModel(input_size, hidden_size, output_size, dropout=dropout, cnn_channels=cnn_channels, kernel_size=kernel_size)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # 训练与验证
    patience = 10
    best_val_loss = float('inf')
    early_stop_counter = 0
    epochs = 100

    # 训练循环
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = model(X_batch)  # 前向传播
            loss = criterion(y_pred.squeeze(), y_batch)  # 计算损失
            loss.backward()  # 反向传播
            optimizer.step()  # 更新参数
            train_loss += loss.item()
        
        train_loss /= len(train_loader)

        # 验证阶段
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                y_pred = model(X_batch).squeeze()
                loss = criterion(y_pred, y_batch)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # 早停机制
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            torch.save(model.state_dict(), f'best_model_fold{fold}.pth')  # 保存最佳模型
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print("Early stopping triggered")
            break

    # 保存训练和验证损失
    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # 测试集评估
    model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
    model.eval()
    y_preds = []
    y_trues = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            y_pred = model(X_batch).squeeze()
            y_preds.extend(y_pred.squeeze().tolist())
            y_trues.extend(y_batch.tolist())
            loss = criterion(y_pred.squeeze(), y_batch)

    mae = mean_absolute_error(y_trues, y_preds)
    rmse = mean_squared_error(y_trues, y_preds, squared=False)
    maes.append(mae)
    rmses.append(rmse)

    print(f"Fold {fold} - MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# 计算平均损失
avg_train_loss = np.mean(train_losses)
avg_val_loss = np.mean(val_losses)
avg_mae = np.mean(maes)
avg_rmse = np.mean(rmses)

print(f"Average Train Loss: {avg_train_loss:.4f}")
print(f"Average Val Loss: {avg_val_loss:.4f}")
print(f"Average MAE: {avg_mae:.4f}")
print(f"Average RMSE: {avg_rmse:.4f}")
# Out:
# Fold 1/5
# Epoch 1/100, Train Loss: 208.5801, Val Loss: 94.0954
# Epoch 2/100, Train Loss: 87.4629, Val Loss: 76.6271
# Epoch 3/100, Train Loss: 80.4032, Val Loss: 72.1713
# Epoch 4/100, Train Loss: 77.6992, Val Loss: 70.3980
# Epoch 5/100, Train Loss: 74.8989, Val Loss: 69.4222
# Epoch 6/100, Train Loss: 73.1783, Val Loss: 67.1117
# Epoch 7/100, Train Loss: 71.9564, Val Loss: 66.8905
# Epoch 8/100, Train Loss: 71.2526, Val Loss: 68.0847
# Epoch 9/100, Train Loss: 70.2125, Val Loss: 66.2398
# Epoch 10/100, Train Loss: 68.6244, Val Loss: 66.3271
# Epoch 11/100, Train Loss: 67.5389, Val Loss: 64.9186
# Epoch 12/100, Train Loss: 67.0646, Val Loss: 62.9630
# Epoch 13/100, Train Loss: 65.7044, Val Loss: 66.4893
# Epoch 14/100, Train Loss: 64.9073, Val Loss: 61.8055
# Epoch 15/100, Train Loss: 63.9947, Val Loss: 61.3962
# Epoch 16/100, Train Loss: 62.8527, Val Loss: 62.0814
# Epoch 17/100, Train Loss: 62.0812, Val Loss: 59.1969
# Epoch 18/100, Train Loss: 60.3634, Val Loss: 59.4344
# Epoch 19/100, Train Loss: 59.9557, Val Loss: 60.3883
# Epoch 20/100, Train Loss: 58.9177, Val Loss: 57.0615
# Epoch 21/100, Train Loss: 58.0075, Val Loss: 55.2333
# Epoch 22/100, Train Loss: 57.3827, Val Loss: 56.8122
# Epoch 23/100, Train Loss: 57.2968, Val Loss: 56.2172
# Epoch 24/100, Train Loss: 55.8225, Val Loss: 57.1896
# Epoch 25/100, Train Loss: 55.3062, Val Loss: 52.4117
# Epoch 26/100, Train Loss: 54.1435, Val Loss: 56.0643
# Epoch 27/100, Train Loss: 53.5670, Val Loss: 52.5032
# Epoch 28/100, Train Loss: 53.3751, Val Loss: 52.0267
# Epoch 29/100, Train Loss: 52.7497, Val Loss: 53.6100
# Epoch 30/100, Train Loss: 51.6913, Val Loss: 51.2488
# Epoch 31/100, Train Loss: 50.5780, Val Loss: 51.7608
# Epoch 32/100, Train Loss: 50.6249, Val Loss: 49.5161
# Epoch 33/100, Train Loss: 49.6131, Val Loss: 49.0198
# Epoch 34/100, Train Loss: 48.7192, Val Loss: 49.3787
# Epoch 35/100, Train Loss: 48.3164, Val Loss: 54.0367
# Epoch 36/100, Train Loss: 47.2636, Val Loss: 48.4432
# Epoch 37/100, Train Loss: 46.6177, Val Loss: 49.1281
# Epoch 38/100, Train Loss: 46.0511, Val Loss: 47.0463
# Epoch 39/100, Train Loss: 45.9039, Val Loss: 47.3897
# Epoch 40/100, Train Loss: 44.2815, Val Loss: 47.8743
# Epoch 41/100, Train Loss: 44.8343, Val Loss: 44.2674
# Epoch 42/100, Train Loss: 43.0066, Val Loss: 45.3225
# Epoch 43/100, Train Loss: 42.6264, Val Loss: 43.2149
# Epoch 44/100, Train Loss: 41.8488, Val Loss: 44.1235
# Epoch 45/100, Train Loss: 41.9272, Val Loss: 43.4907
# Epoch 46/100, Train Loss: 41.0786, Val Loss: 44.0482
# Epoch 47/100, Train Loss: 41.5482, Val Loss: 41.8844
# Epoch 48/100, Train Loss: 40.3928, Val Loss: 42.4557
# Epoch 49/100, Train Loss: 40.1202, Val Loss: 42.1084
# Epoch 50/100, Train Loss: 39.5083, Val Loss: 41.8083
# Epoch 51/100, Train Loss: 38.8447, Val Loss: 40.7257
# Epoch 52/100, Train Loss: 40.4726, Val Loss: 40.1160
# Epoch 53/100, Train Loss: 38.1106, Val Loss: 39.7407
# Epoch 54/100, Train Loss: 37.1809, Val Loss: 39.9843
# Epoch 55/100, Train Loss: 37.4018, Val Loss: 40.2773
# Epoch 56/100, Train Loss: 36.8515, Val Loss: 38.9573
# Epoch 57/100, Train Loss: 36.4584, Val Loss: 40.3421
# Epoch 58/100, Train Loss: 36.2615, Val Loss: 38.2256
# Epoch 59/100, Train Loss: 35.9462, Val Loss: 37.5672
# Epoch 60/100, Train Loss: 35.8448, Val Loss: 38.4806
# Epoch 61/100, Train Loss: 35.6438, Val Loss: 38.3558
# Epoch 62/100, Train Loss: 34.1827, Val Loss: 40.3160
# Epoch 63/100, Train Loss: 34.4632, Val Loss: 37.7513
# Epoch 64/100, Train Loss: 34.1761, Val Loss: 37.6126
# Epoch 65/100, Train Loss: 33.6153, Val Loss: 37.0803
# Epoch 66/100, Train Loss: 33.5425, Val Loss: 37.8806
# Epoch 67/100, Train Loss: 32.9670, Val Loss: 37.1467
# Epoch 68/100, Train Loss: 33.0683, Val Loss: 37.3917
# Epoch 69/100, Train Loss: 32.5749, Val Loss: 36.0547
# Epoch 70/100, Train Loss: 32.5053, Val Loss: 40.0088
# Epoch 71/100, Train Loss: 32.1831, Val Loss: 39.0883
# Epoch 72/100, Train Loss: 31.4676, Val Loss: 36.3773
# Epoch 73/100, Train Loss: 31.6490, Val Loss: 35.3430
# Epoch 74/100, Train Loss: 31.3912, Val Loss: 35.6384
# Epoch 75/100, Train Loss: 31.7872, Val Loss: 34.4311
# Epoch 76/100, Train Loss: 30.8593, Val Loss: 35.6240
# Epoch 77/100, Train Loss: 31.2314, Val Loss: 33.8300
# Epoch 78/100, Train Loss: 30.6251, Val Loss: 34.2093
# Epoch 79/100, Train Loss: 30.5628, Val Loss: 34.7816
# Epoch 80/100, Train Loss: 29.8615, Val Loss: 34.7219
# Epoch 81/100, Train Loss: 29.9328, Val Loss: 35.4536
# Epoch 82/100, Train Loss: 29.8195, Val Loss: 35.2982
# Epoch 83/100, Train Loss: 29.9009, Val Loss: 33.9369
# Epoch 84/100, Train Loss: 29.7268, Val Loss: 34.1284
# Epoch 85/100, Train Loss: 29.7134, Val Loss: 33.8618
# Epoch 86/100, Train Loss: 29.0493, Val Loss: 33.7151
# Epoch 87/100, Train Loss: 29.0818, Val Loss: 34.8703
# Epoch 88/100, Train Loss: 28.7655, Val Loss: 34.3596
# Epoch 89/100, Train Loss: 29.0444, Val Loss: 33.9256
# Epoch 90/100, Train Loss: 28.4168, Val Loss: 34.0606
# Epoch 91/100, Train Loss: 29.1078, Val Loss: 33.9807
# Epoch 92/100, Train Loss: 28.3405, Val Loss: 34.6821
# Epoch 93/100, Train Loss: 27.7036, Val Loss: 34.8718
# Epoch 94/100, Train Loss: 27.8786, Val Loss: 33.1978
# Epoch 95/100, Train Loss: 28.1825, Val Loss: 34.3443
# Epoch 96/100, Train Loss: 27.9769, Val Loss: 33.6409
# Epoch 97/100, Train Loss: 27.7470, Val Loss: 33.3358
# Epoch 98/100, Train Loss: 27.1920, Val Loss: 33.9071
# Epoch 99/100, Train Loss: 27.2539, Val Loss: 34.1016
# Epoch 100/100, Train Loss: 27.4588, Val Loss: 32.6446
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_74404/865577088.py:190: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 1 - MAE: 4.0742, RMSE: 5.7106
# Fold 2/5
# Epoch 1/100, Train Loss: 206.5955, Val Loss: 99.7624
# Epoch 2/100, Train Loss: 85.1305, Val Loss: 82.9306
# Epoch 3/100, Train Loss: 78.1954, Val Loss: 79.1361
# Epoch 4/100, Train Loss: 75.5339, Val Loss: 76.0428
# Epoch 5/100, Train Loss: 73.7041, Val Loss: 74.1541
# Epoch 6/100, Train Loss: 72.2009, Val Loss: 73.3696
# Epoch 7/100, Train Loss: 70.6865, Val Loss: 71.5918
# Epoch 8/100, Train Loss: 69.7771, Val Loss: 70.1584
# Epoch 9/100, Train Loss: 69.0219, Val Loss: 68.8362
# Epoch 10/100, Train Loss: 68.2005, Val Loss: 69.4584
# Epoch 11/100, Train Loss: 67.2638, Val Loss: 69.0474
# Epoch 12/100, Train Loss: 66.1681, Val Loss: 66.6549
# Epoch 13/100, Train Loss: 64.8201, Val Loss: 65.7309
# Epoch 14/100, Train Loss: 65.1512, Val Loss: 67.3866
# Epoch 15/100, Train Loss: 64.2776, Val Loss: 64.7903
# Epoch 16/100, Train Loss: 62.4661, Val Loss: 62.9349
# Epoch 17/100, Train Loss: 61.7621, Val Loss: 62.9392
# Epoch 18/100, Train Loss: 61.4323, Val Loss: 60.6760
# Epoch 19/100, Train Loss: 60.7925, Val Loss: 61.5799
# Epoch 20/100, Train Loss: 59.3469, Val Loss: 58.8735
# Epoch 21/100, Train Loss: 59.6962, Val Loss: 58.9780
# Epoch 22/100, Train Loss: 57.3003, Val Loss: 58.5796
# Epoch 23/100, Train Loss: 56.8619, Val Loss: 57.9627
# Epoch 24/100, Train Loss: 55.4396, Val Loss: 57.2687
# Epoch 25/100, Train Loss: 55.1347, Val Loss: 55.6344
# Epoch 26/100, Train Loss: 54.9910, Val Loss: 59.3633
# Epoch 27/100, Train Loss: 53.4137, Val Loss: 56.2423
# Epoch 28/100, Train Loss: 53.0627, Val Loss: 53.8342
# Epoch 29/100, Train Loss: 52.0074, Val Loss: 56.7549
# Epoch 30/100, Train Loss: 51.0462, Val Loss: 51.6140
# Epoch 31/100, Train Loss: 50.3610, Val Loss: 52.9728
# Epoch 32/100, Train Loss: 49.9209, Val Loss: 52.0105
# Epoch 33/100, Train Loss: 48.4642, Val Loss: 51.2211
# Epoch 34/100, Train Loss: 48.3678, Val Loss: 49.0206
# Epoch 35/100, Train Loss: 47.4633, Val Loss: 51.7284
# Epoch 36/100, Train Loss: 46.3385, Val Loss: 48.7035
# Epoch 37/100, Train Loss: 45.8677, Val Loss: 47.5856
# Epoch 38/100, Train Loss: 45.5310, Val Loss: 47.3888
# Epoch 39/100, Train Loss: 44.7968, Val Loss: 48.3000
# Epoch 40/100, Train Loss: 44.1116, Val Loss: 45.4471
# Epoch 41/100, Train Loss: 43.0175, Val Loss: 45.6633
# Epoch 42/100, Train Loss: 42.6537, Val Loss: 48.9772
# Epoch 43/100, Train Loss: 42.4964, Val Loss: 46.1474
# Epoch 44/100, Train Loss: 42.2535, Val Loss: 43.5355
# Epoch 45/100, Train Loss: 40.8093, Val Loss: 44.5586
# Epoch 46/100, Train Loss: 41.1938, Val Loss: 44.1237
# Epoch 47/100, Train Loss: 40.8638, Val Loss: 42.2012
# Epoch 48/100, Train Loss: 39.9806, Val Loss: 46.2889
# Epoch 49/100, Train Loss: 39.3170, Val Loss: 41.6535
# Epoch 50/100, Train Loss: 38.6628, Val Loss: 41.6432
# Epoch 51/100, Train Loss: 38.2408, Val Loss: 41.9724
# Epoch 52/100, Train Loss: 38.2288, Val Loss: 43.5453
# Epoch 53/100, Train Loss: 37.5336, Val Loss: 41.3898
# Epoch 54/100, Train Loss: 37.3242, Val Loss: 39.3350
# Epoch 55/100, Train Loss: 36.2043, Val Loss: 41.6779
# Epoch 56/100, Train Loss: 36.2886, Val Loss: 39.8588
# Epoch 57/100, Train Loss: 35.9498, Val Loss: 38.2675
# Epoch 58/100, Train Loss: 35.5621, Val Loss: 38.5353
# Epoch 59/100, Train Loss: 35.3576, Val Loss: 39.0478
# Epoch 60/100, Train Loss: 34.5034, Val Loss: 38.4979
# Epoch 61/100, Train Loss: 33.8638, Val Loss: 38.9815
# Epoch 62/100, Train Loss: 33.9507, Val Loss: 38.5857
# Epoch 63/100, Train Loss: 33.8524, Val Loss: 39.1954
# Epoch 64/100, Train Loss: 33.0951, Val Loss: 39.8332
# Epoch 65/100, Train Loss: 33.2982, Val Loss: 37.3061
# Epoch 66/100, Train Loss: 32.9164, Val Loss: 40.3302
# Epoch 67/100, Train Loss: 32.6357, Val Loss: 39.4505
# Epoch 68/100, Train Loss: 32.6187, Val Loss: 38.0302
# Epoch 69/100, Train Loss: 31.9954, Val Loss: 37.8806
# Epoch 70/100, Train Loss: 32.0203, Val Loss: 36.2502
# Epoch 71/100, Train Loss: 31.6514, Val Loss: 36.4803
# Epoch 72/100, Train Loss: 30.7519, Val Loss: 38.3704
# Epoch 73/100, Train Loss: 31.1628, Val Loss: 37.1764
# Epoch 74/100, Train Loss: 30.5898, Val Loss: 36.5586
# Epoch 75/100, Train Loss: 32.2158, Val Loss: 36.9961
# Epoch 76/100, Train Loss: 29.8834, Val Loss: 35.7604
# Epoch 77/100, Train Loss: 30.6225, Val Loss: 37.6376
# Epoch 78/100, Train Loss: 30.2257, Val Loss: 36.5868
# Epoch 79/100, Train Loss: 29.7639, Val Loss: 34.6639
# Epoch 80/100, Train Loss: 29.3261, Val Loss: 34.7291
# Epoch 81/100, Train Loss: 29.6207, Val Loss: 34.6785
# Epoch 82/100, Train Loss: 29.2711, Val Loss: 35.3033
# Epoch 83/100, Train Loss: 29.7802, Val Loss: 35.0176
# Epoch 84/100, Train Loss: 28.8508, Val Loss: 35.6691
# Epoch 85/100, Train Loss: 28.8508, Val Loss: 34.8497
# Epoch 86/100, Train Loss: 29.1413, Val Loss: 35.1614
# Epoch 87/100, Train Loss: 28.9024, Val Loss: 36.1562
# Epoch 88/100, Train Loss: 28.3822, Val Loss: 34.1960
# Epoch 89/100, Train Loss: 28.7994, Val Loss: 34.1131
# Epoch 90/100, Train Loss: 27.8066, Val Loss: 34.7843
# Epoch 91/100, Train Loss: 27.6069, Val Loss: 34.1842
# Epoch 92/100, Train Loss: 27.8592, Val Loss: 34.9563
# Epoch 93/100, Train Loss: 27.2412, Val Loss: 35.8010
# Epoch 94/100, Train Loss: 27.8924, Val Loss: 34.6196
# Epoch 95/100, Train Loss: 27.1807, Val Loss: 35.3684
# Epoch 96/100, Train Loss: 26.9914, Val Loss: 34.2742
# Epoch 97/100, Train Loss: 27.1009, Val Loss: 35.2900
# Epoch 98/100, Train Loss: 26.7994, Val Loss: 34.5010
# Epoch 99/100, Train Loss: 26.3518, Val Loss: 34.1082
# Epoch 100/100, Train Loss: 27.1982, Val Loss: 34.7948
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_74404/865577088.py:190: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 2 - MAE: 4.1088, RMSE: 5.8390
# Fold 3/5
# Epoch 1/100, Train Loss: 208.5118, Val Loss: 94.9608
# Epoch 2/100, Train Loss: 86.3270, Val Loss: 77.5573
# Epoch 3/100, Train Loss: 79.8005, Val Loss: 74.0864
# Epoch 4/100, Train Loss: 76.1881, Val Loss: 72.3546
# Epoch 5/100, Train Loss: 74.3981, Val Loss: 68.0801
# Epoch 6/100, Train Loss: 72.6422, Val Loss: 67.9173
# Epoch 7/100, Train Loss: 70.4719, Val Loss: 68.2046
# Epoch 8/100, Train Loss: 69.8750, Val Loss: 66.1362
# Epoch 9/100, Train Loss: 68.6691, Val Loss: 65.8954
# Epoch 10/100, Train Loss: 68.0454, Val Loss: 64.3695
# Epoch 11/100, Train Loss: 67.0619, Val Loss: 62.1955
# Epoch 12/100, Train Loss: 65.9232, Val Loss: 61.8646
# Epoch 13/100, Train Loss: 65.4004, Val Loss: 63.7337
# Epoch 14/100, Train Loss: 64.3127, Val Loss: 60.7713
# Epoch 15/100, Train Loss: 63.7261, Val Loss: 60.5168
# Epoch 16/100, Train Loss: 61.9694, Val Loss: 58.3113
# Epoch 17/100, Train Loss: 61.8421, Val Loss: 55.8532
# Epoch 18/100, Train Loss: 60.1742, Val Loss: 55.4431
# Epoch 19/100, Train Loss: 59.4188, Val Loss: 55.6178
# Epoch 20/100, Train Loss: 58.9598, Val Loss: 56.0223
# Epoch 21/100, Train Loss: 58.1733, Val Loss: 53.7711
# Epoch 22/100, Train Loss: 57.3652, Val Loss: 53.2737
# Epoch 23/100, Train Loss: 57.0182, Val Loss: 52.4184
# Epoch 24/100, Train Loss: 55.1452, Val Loss: 51.7551
# Epoch 25/100, Train Loss: 54.5844, Val Loss: 50.2319
# Epoch 26/100, Train Loss: 53.7688, Val Loss: 49.3644
# Epoch 27/100, Train Loss: 52.5971, Val Loss: 50.2472
# Epoch 28/100, Train Loss: 52.8588, Val Loss: 48.9792
# Epoch 29/100, Train Loss: 51.7036, Val Loss: 48.4639
# Epoch 30/100, Train Loss: 50.5304, Val Loss: 49.5494
# Epoch 31/100, Train Loss: 49.7483, Val Loss: 48.1694
# Epoch 32/100, Train Loss: 49.5064, Val Loss: 47.7592
# Epoch 33/100, Train Loss: 49.4925, Val Loss: 47.0073
# Epoch 34/100, Train Loss: 49.2299, Val Loss: 47.1479
# Epoch 35/100, Train Loss: 47.7504, Val Loss: 44.9762
# Epoch 36/100, Train Loss: 47.4751, Val Loss: 44.9649
# Epoch 37/100, Train Loss: 46.9534, Val Loss: 44.8104
# Epoch 38/100, Train Loss: 46.7842, Val Loss: 43.4135
# Epoch 39/100, Train Loss: 46.2493, Val Loss: 48.1968
# Epoch 40/100, Train Loss: 46.8628, Val Loss: 45.0626
# Epoch 41/100, Train Loss: 45.3532, Val Loss: 46.0410
# Epoch 42/100, Train Loss: 44.9655, Val Loss: 43.2152
# Epoch 43/100, Train Loss: 45.1688, Val Loss: 42.6924
# Epoch 44/100, Train Loss: 44.7033, Val Loss: 43.0411
# Epoch 45/100, Train Loss: 43.3960, Val Loss: 42.6681
# Epoch 46/100, Train Loss: 43.4214, Val Loss: 44.7158
# Epoch 47/100, Train Loss: 43.4377, Val Loss: 42.9344
# Epoch 48/100, Train Loss: 42.6624, Val Loss: 42.2103
# Epoch 49/100, Train Loss: 43.2753, Val Loss: 42.3108
# Epoch 50/100, Train Loss: 41.8851, Val Loss: 42.1332
# Epoch 51/100, Train Loss: 41.4301, Val Loss: 42.8128
# Epoch 52/100, Train Loss: 40.9808, Val Loss: 41.3039
# Epoch 53/100, Train Loss: 41.1074, Val Loss: 40.0548
# Epoch 54/100, Train Loss: 40.0424, Val Loss: 40.8702
# Epoch 55/100, Train Loss: 39.7192, Val Loss: 39.8488
# Epoch 56/100, Train Loss: 39.1593, Val Loss: 39.6879
# Epoch 57/100, Train Loss: 39.4047, Val Loss: 39.0232
# Epoch 58/100, Train Loss: 38.3765, Val Loss: 39.5978
# Epoch 59/100, Train Loss: 38.9069, Val Loss: 38.5281
# Epoch 60/100, Train Loss: 37.4205, Val Loss: 38.8753
# Epoch 61/100, Train Loss: 38.3582, Val Loss: 39.2942
# Epoch 62/100, Train Loss: 36.9248, Val Loss: 38.0316
# Epoch 63/100, Train Loss: 37.2202, Val Loss: 38.8113
# Epoch 64/100, Train Loss: 36.3941, Val Loss: 37.4425
# Epoch 65/100, Train Loss: 36.2107, Val Loss: 39.0325
# Epoch 66/100, Train Loss: 36.1240, Val Loss: 36.6929
# Epoch 67/100, Train Loss: 36.0764, Val Loss: 36.8420
# Epoch 68/100, Train Loss: 35.9771, Val Loss: 37.0666
# Epoch 69/100, Train Loss: 35.4395, Val Loss: 36.4508
# Epoch 70/100, Train Loss: 34.8772, Val Loss: 36.7080
# Epoch 71/100, Train Loss: 34.1205, Val Loss: 36.8556
# Epoch 72/100, Train Loss: 33.8561, Val Loss: 36.0455
# Epoch 73/100, Train Loss: 34.4168, Val Loss: 35.8051
# Epoch 74/100, Train Loss: 33.3105, Val Loss: 37.4080
# Epoch 75/100, Train Loss: 33.3212, Val Loss: 34.0532
# Epoch 76/100, Train Loss: 33.3451, Val Loss: 34.6317
# Epoch 77/100, Train Loss: 33.0512, Val Loss: 34.4501
# Epoch 78/100, Train Loss: 32.1193, Val Loss: 34.6692
# Epoch 79/100, Train Loss: 33.0887, Val Loss: 35.6757
# Epoch 80/100, Train Loss: 31.8921, Val Loss: 35.6090
# Epoch 81/100, Train Loss: 31.8395, Val Loss: 35.7793
# Epoch 82/100, Train Loss: 31.8366, Val Loss: 34.2266
# Epoch 83/100, Train Loss: 31.4402, Val Loss: 34.3295
# Epoch 84/100, Train Loss: 31.2566, Val Loss: 32.9019
# Epoch 85/100, Train Loss: 30.8258, Val Loss: 34.6716
# Epoch 86/100, Train Loss: 30.9155, Val Loss: 34.4967
# Epoch 87/100, Train Loss: 30.8923, Val Loss: 33.8122
# Epoch 88/100, Train Loss: 30.9622, Val Loss: 34.7028
# Epoch 89/100, Train Loss: 30.4377, Val Loss: 33.9205
# Epoch 90/100, Train Loss: 29.4322, Val Loss: 35.2935
# Epoch 91/100, Train Loss: 29.8930, Val Loss: 35.2862
# Epoch 92/100, Train Loss: 30.2196, Val Loss: 33.1771
# Epoch 93/100, Train Loss: 29.7740, Val Loss: 33.9864
# Epoch 94/100, Train Loss: 29.7882, Val Loss: 34.0290
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_74404/865577088.py:190: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 3 - MAE: 4.1326, RMSE: 5.7352
# Fold 4/5
# Epoch 1/100, Train Loss: 213.6399, Val Loss: 97.5329
# Epoch 2/100, Train Loss: 86.3934, Val Loss: 83.4256
# Epoch 3/100, Train Loss: 79.4871, Val Loss: 79.1585
# Epoch 4/100, Train Loss: 75.4591, Val Loss: 76.4334
# Epoch 5/100, Train Loss: 73.2496, Val Loss: 74.6247
# Epoch 6/100, Train Loss: 71.4845, Val Loss: 72.8434
# Epoch 7/100, Train Loss: 70.2884, Val Loss: 71.2589
# Epoch 8/100, Train Loss: 68.5123, Val Loss: 70.5311
# Epoch 9/100, Train Loss: 67.9852, Val Loss: 69.6697
# Epoch 10/100, Train Loss: 67.1305, Val Loss: 68.8110
# Epoch 11/100, Train Loss: 66.5886, Val Loss: 68.3395
# Epoch 12/100, Train Loss: 65.1384, Val Loss: 72.7443
# Epoch 13/100, Train Loss: 64.0943, Val Loss: 67.5077
# Epoch 14/100, Train Loss: 63.6671, Val Loss: 64.6188
# Epoch 15/100, Train Loss: 63.0686, Val Loss: 64.3293
# Epoch 16/100, Train Loss: 61.6194, Val Loss: 64.6258
# Epoch 17/100, Train Loss: 61.3892, Val Loss: 64.0613
# Epoch 18/100, Train Loss: 60.3416, Val Loss: 63.3575
# Epoch 19/100, Train Loss: 59.6498, Val Loss: 62.0581
# Epoch 20/100, Train Loss: 59.0278, Val Loss: 62.5228
# Epoch 21/100, Train Loss: 58.8522, Val Loss: 69.7094
# Epoch 22/100, Train Loss: 58.1452, Val Loss: 62.9360
# Epoch 23/100, Train Loss: 56.9971, Val Loss: 62.3325
# Epoch 24/100, Train Loss: 55.3521, Val Loss: 57.6256
# Epoch 25/100, Train Loss: 54.9598, Val Loss: 57.7001
# Epoch 26/100, Train Loss: 54.0497, Val Loss: 58.0653
# Epoch 27/100, Train Loss: 54.1713, Val Loss: 57.4619
# Epoch 28/100, Train Loss: 52.1314, Val Loss: 57.8365
# Epoch 29/100, Train Loss: 52.2398, Val Loss: 56.1361
# Epoch 30/100, Train Loss: 51.0996, Val Loss: 54.8293
# Epoch 31/100, Train Loss: 50.3355, Val Loss: 53.5410
# Epoch 32/100, Train Loss: 50.1596, Val Loss: 53.7414
# Epoch 33/100, Train Loss: 49.2978, Val Loss: 52.5507
# Epoch 34/100, Train Loss: 48.9999, Val Loss: 51.6486
# Epoch 35/100, Train Loss: 49.2729, Val Loss: 54.9047
# Epoch 36/100, Train Loss: 46.7928, Val Loss: 50.8471
# Epoch 37/100, Train Loss: 46.7925, Val Loss: 51.0584
# Epoch 38/100, Train Loss: 46.6286, Val Loss: 50.7632
# Epoch 39/100, Train Loss: 45.4378, Val Loss: 49.2756
# Epoch 40/100, Train Loss: 45.3236, Val Loss: 49.5352
# Epoch 41/100, Train Loss: 44.4566, Val Loss: 49.1325
# Epoch 42/100, Train Loss: 43.5310, Val Loss: 48.1729
# Epoch 43/100, Train Loss: 42.2688, Val Loss: 49.3005
# Epoch 44/100, Train Loss: 43.2087, Val Loss: 46.7131
# Epoch 45/100, Train Loss: 42.2938, Val Loss: 48.6117
# Epoch 46/100, Train Loss: 41.3521, Val Loss: 46.2775
# Epoch 47/100, Train Loss: 41.6620, Val Loss: 49.2273
# Epoch 48/100, Train Loss: 40.4439, Val Loss: 47.6624
# Epoch 49/100, Train Loss: 40.2776, Val Loss: 45.4036
# Epoch 50/100, Train Loss: 40.1307, Val Loss: 44.7789
# Epoch 51/100, Train Loss: 38.7968, Val Loss: 47.2548
# Epoch 52/100, Train Loss: 39.0607, Val Loss: 43.1391
# Epoch 53/100, Train Loss: 38.3453, Val Loss: 43.6845
# Epoch 54/100, Train Loss: 37.9914, Val Loss: 43.1096
# Epoch 55/100, Train Loss: 38.1915, Val Loss: 43.9687
# Epoch 56/100, Train Loss: 36.9809, Val Loss: 42.5761
# Epoch 57/100, Train Loss: 36.6251, Val Loss: 41.7381
# Epoch 58/100, Train Loss: 36.5493, Val Loss: 42.1152
# Epoch 59/100, Train Loss: 38.4454, Val Loss: 46.0010
# Epoch 60/100, Train Loss: 36.8084, Val Loss: 42.7874
# Epoch 61/100, Train Loss: 35.5236, Val Loss: 39.9145
# Epoch 62/100, Train Loss: 34.7670, Val Loss: 40.0635
# Epoch 63/100, Train Loss: 34.9607, Val Loss: 40.9847
# Epoch 64/100, Train Loss: 34.9895, Val Loss: 39.2558
# Epoch 65/100, Train Loss: 34.3760, Val Loss: 39.0461
# Epoch 66/100, Train Loss: 33.3900, Val Loss: 38.9236
# Epoch 67/100, Train Loss: 34.1623, Val Loss: 39.1695
# Epoch 68/100, Train Loss: 33.7795, Val Loss: 40.0572
# Epoch 69/100, Train Loss: 33.1676, Val Loss: 38.4124
# Epoch 70/100, Train Loss: 33.5938, Val Loss: 40.2513
# Epoch 71/100, Train Loss: 32.8687, Val Loss: 38.6735
# Epoch 72/100, Train Loss: 32.6216, Val Loss: 38.5523
# Epoch 73/100, Train Loss: 32.2123, Val Loss: 40.4257
# Epoch 74/100, Train Loss: 31.8482, Val Loss: 36.9120
# Epoch 75/100, Train Loss: 31.9753, Val Loss: 39.9574
# Epoch 76/100, Train Loss: 31.4205, Val Loss: 37.1392
# Epoch 77/100, Train Loss: 31.3748, Val Loss: 37.7818
# Epoch 78/100, Train Loss: 31.2303, Val Loss: 37.6806
# Epoch 79/100, Train Loss: 31.0850, Val Loss: 37.6699
# Epoch 80/100, Train Loss: 30.4866, Val Loss: 37.0117
# Epoch 81/100, Train Loss: 29.9510, Val Loss: 42.4452
# Epoch 82/100, Train Loss: 30.7911, Val Loss: 38.5906
# Epoch 83/100, Train Loss: 30.9155, Val Loss: 37.7704
# Epoch 84/100, Train Loss: 30.1423, Val Loss: 37.7443
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_74404/865577088.py:190: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 4 - MAE: 4.2302, RMSE: 6.0783
# Fold 5/5
# Epoch 1/100, Train Loss: 208.4260, Val Loss: 93.3030
# Epoch 2/100, Train Loss: 86.2124, Val Loss: 76.3103
# Epoch 3/100, Train Loss: 79.0825, Val Loss: 79.8392
# Epoch 4/100, Train Loss: 74.6233, Val Loss: 68.9157
# Epoch 5/100, Train Loss: 72.8044, Val Loss: 67.8636
# Epoch 6/100, Train Loss: 71.7495, Val Loss: 66.8940
# Epoch 7/100, Train Loss: 70.2491, Val Loss: 65.3763
# Epoch 8/100, Train Loss: 69.2111, Val Loss: 65.3427
# Epoch 9/100, Train Loss: 67.8949, Val Loss: 66.4354
# Epoch 10/100, Train Loss: 66.8587, Val Loss: 63.8238
# Epoch 11/100, Train Loss: 66.6459, Val Loss: 63.1176
# Epoch 12/100, Train Loss: 64.5584, Val Loss: 61.1291
# Epoch 13/100, Train Loss: 64.5377, Val Loss: 59.7301
# Epoch 14/100, Train Loss: 62.7974, Val Loss: 60.8087
# Epoch 15/100, Train Loss: 62.5977, Val Loss: 66.8538
# Epoch 16/100, Train Loss: 61.7071, Val Loss: 59.4470
# Epoch 17/100, Train Loss: 60.9928, Val Loss: 57.3023
# Epoch 18/100, Train Loss: 60.1095, Val Loss: 57.8217
# Epoch 19/100, Train Loss: 59.5952, Val Loss: 56.1219
# Epoch 20/100, Train Loss: 59.2080, Val Loss: 58.4429
# Epoch 21/100, Train Loss: 58.8323, Val Loss: 58.8283
# Epoch 22/100, Train Loss: 57.0492, Val Loss: 55.6890
# Epoch 23/100, Train Loss: 57.3045, Val Loss: 57.3065
# Epoch 24/100, Train Loss: 56.8959, Val Loss: 54.5774
# Epoch 25/100, Train Loss: 55.9859, Val Loss: 53.6771
# Epoch 26/100, Train Loss: 55.2951, Val Loss: 54.4997
# Epoch 27/100, Train Loss: 54.7529, Val Loss: 52.5159
# Epoch 28/100, Train Loss: 54.5044, Val Loss: 54.3125
# Epoch 29/100, Train Loss: 53.7341, Val Loss: 55.4226
# Epoch 30/100, Train Loss: 53.5294, Val Loss: 53.2986
# Epoch 31/100, Train Loss: 52.5770, Val Loss: 51.6687
# Epoch 32/100, Train Loss: 52.1109, Val Loss: 53.0901
# Epoch 33/100, Train Loss: 52.3103, Val Loss: 50.2045
# Epoch 34/100, Train Loss: 51.1028, Val Loss: 50.3937
# Epoch 35/100, Train Loss: 49.2497, Val Loss: 52.0714
# Epoch 36/100, Train Loss: 49.3742, Val Loss: 48.3838
# Epoch 37/100, Train Loss: 48.7423, Val Loss: 48.3761
# Epoch 38/100, Train Loss: 48.5872, Val Loss: 50.3782
# Epoch 39/100, Train Loss: 47.7934, Val Loss: 47.2192
# Epoch 40/100, Train Loss: 47.3170, Val Loss: 48.1856
# Epoch 41/100, Train Loss: 46.6648, Val Loss: 46.9462
# Epoch 42/100, Train Loss: 45.8398, Val Loss: 46.8479
# Epoch 43/100, Train Loss: 45.8767, Val Loss: 45.4070
# Epoch 44/100, Train Loss: 45.0363, Val Loss: 47.3137
# Epoch 45/100, Train Loss: 45.0359, Val Loss: 44.8786
# Epoch 46/100, Train Loss: 44.8627, Val Loss: 45.3381
# Epoch 47/100, Train Loss: 44.0022, Val Loss: 44.0908
# Epoch 48/100, Train Loss: 42.1861, Val Loss: 43.1743
# Epoch 49/100, Train Loss: 42.7058, Val Loss: 43.6109
# Epoch 50/100, Train Loss: 41.6374, Val Loss: 43.5282
# Epoch 51/100, Train Loss: 41.6466, Val Loss: 43.5934
# Epoch 52/100, Train Loss: 41.0240, Val Loss: 42.5404
# Epoch 53/100, Train Loss: 40.6737, Val Loss: 43.2183
# Epoch 54/100, Train Loss: 39.9882, Val Loss: 42.0000
# Epoch 55/100, Train Loss: 40.0725, Val Loss: 42.5373
# Epoch 56/100, Train Loss: 40.0544, Val Loss: 40.7268
# Epoch 57/100, Train Loss: 38.9890, Val Loss: 42.1883
# Epoch 58/100, Train Loss: 39.5481, Val Loss: 41.7849
# Epoch 59/100, Train Loss: 38.8523, Val Loss: 42.1341
# Epoch 60/100, Train Loss: 38.4762, Val Loss: 39.4590
# Epoch 61/100, Train Loss: 38.0660, Val Loss: 38.8929
# Epoch 62/100, Train Loss: 37.1123, Val Loss: 39.9745
# Epoch 63/100, Train Loss: 37.9406, Val Loss: 39.7442
# Epoch 64/100, Train Loss: 37.2786, Val Loss: 38.4851
# Epoch 65/100, Train Loss: 36.0053, Val Loss: 39.7549
# Epoch 66/100, Train Loss: 36.1351, Val Loss: 37.7131
# Epoch 67/100, Train Loss: 35.7877, Val Loss: 37.9017
# Epoch 68/100, Train Loss: 35.7793, Val Loss: 39.1484
# Epoch 69/100, Train Loss: 35.3488, Val Loss: 37.4087
# Epoch 70/100, Train Loss: 35.1954, Val Loss: 38.1428
# Epoch 71/100, Train Loss: 34.4316, Val Loss: 38.6175
# Epoch 72/100, Train Loss: 34.3520, Val Loss: 36.1423
# Epoch 73/100, Train Loss: 34.2268, Val Loss: 36.3148
# Epoch 74/100, Train Loss: 33.5045, Val Loss: 36.6000
# Epoch 75/100, Train Loss: 34.3175, Val Loss: 36.2347
# Epoch 76/100, Train Loss: 33.1053, Val Loss: 36.0959
# Epoch 77/100, Train Loss: 32.7774, Val Loss: 36.7500
# Epoch 78/100, Train Loss: 32.9736, Val Loss: 35.5876
# Epoch 79/100, Train Loss: 31.9695, Val Loss: 34.7700
# Epoch 80/100, Train Loss: 32.0818, Val Loss: 35.2011
# Epoch 81/100, Train Loss: 31.8306, Val Loss: 35.3395
# Epoch 82/100, Train Loss: 31.2603, Val Loss: 37.6736
# Epoch 83/100, Train Loss: 31.9991, Val Loss: 34.8186
# Epoch 84/100, Train Loss: 31.0592, Val Loss: 34.3895
# Epoch 85/100, Train Loss: 30.7469, Val Loss: 34.2250
# Epoch 86/100, Train Loss: 30.5099, Val Loss: 34.4763
# Epoch 87/100, Train Loss: 29.8243, Val Loss: 33.8064
# Epoch 88/100, Train Loss: 30.2738, Val Loss: 34.4622
# Epoch 89/100, Train Loss: 30.3877, Val Loss: 33.4870
# Epoch 90/100, Train Loss: 29.5549, Val Loss: 33.5539
# Epoch 91/100, Train Loss: 29.9989, Val Loss: 33.8322
# Epoch 92/100, Train Loss: 29.8318, Val Loss: 33.7428
# Epoch 93/100, Train Loss: 29.5515, Val Loss: 33.0613
# Epoch 94/100, Train Loss: 29.3263, Val Loss: 34.7499
# Epoch 95/100, Train Loss: 28.9691, Val Loss: 34.3447
# Epoch 96/100, Train Loss: 28.4937, Val Loss: 33.9340
# Epoch 97/100, Train Loss: 28.9434, Val Loss: 33.4418
# Epoch 98/100, Train Loss: 28.6219, Val Loss: 34.9789
# Epoch 99/100, Train Loss: 28.2495, Val Loss: 33.2158
# Epoch 100/100, Train Loss: 27.9007, Val Loss: 32.7343
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_74404/865577088.py:190: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# Fold 5 - MAE: 4.0758, RMSE: 5.7200
# Average Train Loss: 28.4976
# Average Val Loss: 34.3894
# Average MAE: 4.1243
# Average RMSE: 5.8166
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
