# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_absolute_error, mean_squared_error
import random

# 设置随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# 在代码的开头设置随机种子
set_seed(42)

# 读取数据
data = pd.read_csv('final_50_all.csv')

num_features = ['temperature_2m (°C)', 'apparent_temperature (°C)', 'rain (mm)', 'wind_speed_100m (km/h)']

# 特征工程
data['hour'] = pd.to_datetime(data['hour'])
data['year'] = data['hour'].dt.year
data['month'] = data['hour'].dt.month
data['day'] = data['hour'].dt.day
data['hour_of_day'] = data['hour'].dt.hour
data['weekday'] = data['hour'].dt.weekday

data['hour_sin'] = np.sin(2 * np.pi * data['hour_of_day'] / 24)
data['hour_cos'] = np.cos(2 * np.pi * data['hour_of_day'] / 24)
data['weekday_sin'] = np.sin(2 * np.pi * data['weekday'] / 7)
data['weekday_cos'] = np.cos(2 * np.pi * data['weekday'] / 7)
data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

# 数值特征缩放
scaler = MinMaxScaler()
data[num_features] = scaler.fit_transform(data[num_features])

data.drop(['month','day','hour', 'hour_of_day', 'weekday'], axis=1, inplace=True)

# 提取最终特征和目标
features = num_features + ['hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos','month_sin','month_cos'] 
target = 'ride_count'

X = data[features].values
y = data[target].values

def create_sequences(data, target, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(target[i + sequence_length])
    return np.array(X), np.array(y)

# 设置序列长度
sequence_length = 48  # 例如使用过去24小时的数据预测
X, y = create_sequences(X, y, sequence_length)

# K折交叉验证（5折）
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold = 0

train_losses = []
val_losses = []
maes = []
rmses = []

for train_index, val_index in kf.split(X):
    fold += 1
    print(f"Fold {fold}/{5}")
    
    # 划分训练集和验证集
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # 转换为张量
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

    # 数据加载器
    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=32)
    
    # 定义GRU模型
    class GRUModel(nn.Module):
        def __init__(self, input_size, hidden_size, output_size, dropout, cnn_channels, kernel_size):
            super(GRUModel, self).__init__()
            # 添加 CNN 层
            self.conv1d = nn.Conv1d(in_channels=input_size, out_channels=cnn_channels, kernel_size=kernel_size, padding=kernel_size // 2)
            self.relu = nn.ReLU()

            # GRU 层
            self.gru = nn.GRU(cnn_channels, hidden_size, batch_first=True)
            
            # 全连接层
            self.fc = nn.Linear(hidden_size, output_size)
            self.dropout = nn.Dropout(dropout)
        
        def forward(self, x):
            # CNN 层
            x = x.permute(0, 2, 1)  # 为 Conv1d 调整形状
            x = self.conv1d(x)  # 通过 1D 卷积层
            x = self.relu(x)    # 激活函数
            x = x.permute(0, 2, 1)  # 调整形状回 [batch_size, seq_length, cnn_channels]

            # GRU 层
            out, _ = self.gru(x)  # [batch_size, seq_length, hidden_size]

            # Dropout 和全连接层
            out = self.dropout(out[:, -1, :])  # 取最后一个时间步的输出
            out = self.fc(out)  # 全连接层
            return out

    # 模型参数
    input_size = len(features)  # 输入特征数
    hidden_size = 64           # 隐藏层大小
    output_size = 1            # 输出大小（预测目标变量）
    dropout = 0.2              # Dropout 概率
    cnn_channels = 32         # CNN 输出通道数
    kernel_size = 3            # CNN 卷积核大小

    # 实例化模型
    model = GRUModel(input_size, hidden_size, output_size, dropout=dropout, cnn_channels=cnn_channels, kernel_size=kernel_size)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # 训练与验证
    patience = 10
    best_val_loss = float('inf')
    early_stop_counter = 0
    epochs = 100

    # 训练循环
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = model(X_batch)  # 前向传播
            loss = criterion(y_pred.squeeze(), y_batch)  # 计算损失
            loss.backward()  # 反向传播
            optimizer.step()  # 更新参数
            train_loss += loss.item()
        
        train_loss /= len(train_loader)

        # 验证阶段
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                y_pred = model(X_batch).squeeze()
                loss = criterion(y_pred, y_batch)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # 早停机制
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            torch.save(model.state_dict(), f'best_model_fold{fold}.pth')  # 保存最佳模型
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print("Early stopping triggered")
            break

    # 保存训练和验证损失
    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # 测试集评估
    model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
    model.eval()
    y_preds = []
    y_trues = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            y_pred = model(X_batch).squeeze()
            y_preds.extend(y_pred.squeeze().tolist())
            y_trues.extend(y_batch.tolist())
            loss = criterion(y_pred.squeeze(), y_batch)

    mae = mean_absolute_error(y_trues, y_preds)
    rmse = mean_squared_error(y_trues, y_preds, squared=False)
    maes.append(mae)
    rmses.append(rmse)

    print(f"Fold {fold} - MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# 计算平均损失
avg_train_loss = np.mean(train_losses)
avg_val_loss = np.mean(val_losses)
avg_mae = np.mean(maes)
avg_rmse = np.mean(rmses)

print(f"Average Train Loss: {avg_train_loss:.4f}")
print(f"Average Val Loss: {avg_val_loss:.4f}")
print(f"Average MAE: {avg_mae:.4f}")
print(f"Average RMSE: {avg_rmse:.4f}")

# 预测结果可视化
plt.figure(figsize=(12, 6))
plt.plot(y_trues, label='True Values')
plt.plot(y_preds, label='Predicted Values')
plt.legend()
plt.title('True vs Predicted Ride Counts')
plt.show()
# Out:
# Fold 1/5
# Epoch 1/100, Train Loss: 211.8895, Val Loss: 85.6599
# Epoch 2/100, Train Loss: 88.6651, Val Loss: 70.4291
# Epoch 3/100, Train Loss: 82.0591, Val Loss: 67.6829
# Epoch 4/100, Train Loss: 78.9513, Val Loss: 65.4516
# Epoch 5/100, Train Loss: 75.4269, Val Loss: 62.9589
# Epoch 6/100, Train Loss: 71.9839, Val Loss: 56.2405
# Epoch 7/100, Train Loss: 69.6626, Val Loss: 56.9513
# Epoch 8/100, Train Loss: 68.6928, Val Loss: 58.0876
# Epoch 9/100, Train Loss: 65.9801, Val Loss: 56.5902
# Epoch 10/100, Train Loss: 65.0230, Val Loss: 52.2338
# Epoch 11/100, Train Loss: 63.5771, Val Loss: 53.3956
# Epoch 12/100, Train Loss: 62.0314, Val Loss: 50.7384
# Epoch 13/100, Train Loss: 60.8786, Val Loss: 50.2723
# Epoch 14/100, Train Loss: 58.6697, Val Loss: 48.4112
# Epoch 15/100, Train Loss: 57.4735, Val Loss: 47.3544
# Epoch 16/100, Train Loss: 56.5876, Val Loss: 47.0984
# Epoch 17/100, Train Loss: 55.4515, Val Loss: 47.6233
# Epoch 18/100, Train Loss: 52.9191, Val Loss: 49.4727
# Epoch 19/100, Train Loss: 52.8762, Val Loss: 49.3289
# Epoch 20/100, Train Loss: 51.1103, Val Loss: 43.1636
# Epoch 21/100, Train Loss: 50.2979, Val Loss: 43.4447
# Epoch 22/100, Train Loss: 49.6492, Val Loss: 45.4647
# Epoch 23/100, Train Loss: 48.5251, Val Loss: 42.3558
# Epoch 24/100, Train Loss: 47.9564, Val Loss: 43.6318
# Epoch 25/100, Train Loss: 47.8674, Val Loss: 39.8254
# Epoch 26/100, Train Loss: 47.0407, Val Loss: 40.6966
# Epoch 27/100, Train Loss: 46.1987, Val Loss: 41.2022
# Epoch 28/100, Train Loss: 46.5853, Val Loss: 42.0954
# Epoch 29/100, Train Loss: 45.6621, Val Loss: 38.3035
# Epoch 30/100, Train Loss: 44.8624, Val Loss: 40.4800
# Epoch 31/100, Train Loss: 44.3308, Val Loss: 39.2048
# Epoch 32/100, Train Loss: 43.4818, Val Loss: 38.1319
# Epoch 33/100, Train Loss: 42.9415, Val Loss: 40.2857
# Epoch 34/100, Train Loss: 43.4148, Val Loss: 37.7974
# Epoch 35/100, Train Loss: 42.1107, Val Loss: 35.9875
# Epoch 36/100, Train Loss: 41.5118, Val Loss: 35.9298
# Epoch 37/100, Train Loss: 41.0428, Val Loss: 35.6027
# Epoch 38/100, Train Loss: 41.3538, Val Loss: 37.6206
# Epoch 39/100, Train Loss: 40.3234, Val Loss: 34.4390
# Epoch 40/100, Train Loss: 39.8259, Val Loss: 36.4226
# Epoch 41/100, Train Loss: 39.6667, Val Loss: 35.1347
# Epoch 42/100, Train Loss: 38.8007, Val Loss: 36.7696
# Epoch 43/100, Train Loss: 38.6143, Val Loss: 34.5596
# Epoch 44/100, Train Loss: 37.8476, Val Loss: 34.2615
# Epoch 45/100, Train Loss: 37.4478, Val Loss: 34.2477
# Epoch 46/100, Train Loss: 36.9339, Val Loss: 34.3201
# Epoch 47/100, Train Loss: 37.2985, Val Loss: 33.6341
# Epoch 48/100, Train Loss: 37.0728, Val Loss: 31.6536
# Epoch 49/100, Train Loss: 36.0545, Val Loss: 32.4619
# Epoch 50/100, Train Loss: 35.3662, Val Loss: 33.2448
# Epoch 51/100, Train Loss: 35.3385, Val Loss: 34.2294
# Epoch 52/100, Train Loss: 35.3916, Val Loss: 33.0072
# Epoch 53/100, Train Loss: 34.5421, Val Loss: 31.8810
# Epoch 54/100, Train Loss: 33.9207, Val Loss: 32.3291
# Epoch 55/100, Train Loss: 33.9930, Val Loss: 32.5477
# Epoch 56/100, Train Loss: 33.7258, Val Loss: 31.7397
# Epoch 57/100, Train Loss: 34.1136, Val Loss: 31.1597
# Epoch 58/100, Train Loss: 33.3560, Val Loss: 31.1432
# Epoch 59/100, Train Loss: 32.9077, Val Loss: 32.5603
# Epoch 60/100, Train Loss: 32.9685, Val Loss: 29.9233
# Epoch 61/100, Train Loss: 32.5323, Val Loss: 31.8275
# Epoch 62/100, Train Loss: 32.2027, Val Loss: 30.5781
# Epoch 63/100, Train Loss: 31.9217, Val Loss: 30.3601
# Epoch 64/100, Train Loss: 31.6986, Val Loss: 29.5181
# Epoch 65/100, Train Loss: 32.7124, Val Loss: 30.1360
# Epoch 66/100, Train Loss: 31.1476, Val Loss: 30.9588
# Epoch 67/100, Train Loss: 30.8519, Val Loss: 28.8192
# Epoch 68/100, Train Loss: 30.7766, Val Loss: 31.1072
# Epoch 69/100, Train Loss: 30.7133, Val Loss: 29.7814
# Epoch 70/100, Train Loss: 30.0816, Val Loss: 30.9633
# Epoch 71/100, Train Loss: 30.6699, Val Loss: 31.9757
# Epoch 72/100, Train Loss: 30.3316, Val Loss: 29.9332
# Epoch 73/100, Train Loss: 29.2206, Val Loss: 30.5088
# Epoch 74/100, Train Loss: 29.7535, Val Loss: 29.6348
# Epoch 75/100, Train Loss: 29.3927, Val Loss: 29.1578
# Epoch 76/100, Train Loss: 29.2358, Val Loss: 30.6612
# Epoch 77/100, Train Loss: 30.2296, Val Loss: 29.8581
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_9037/491623669.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 1 - MAE: 3.9323, RMSE: 5.3646
# Fold 2/5
# Epoch 1/100, Train Loss: 221.1281, Val Loss: 98.3726
# Epoch 2/100, Train Loss: 88.6461, Val Loss: 79.0548
# Epoch 3/100, Train Loss: 82.0046, Val Loss: 75.2178
# Epoch 4/100, Train Loss: 78.5717, Val Loss: 71.8692
# Epoch 5/100, Train Loss: 75.8188, Val Loss: 68.5816
# Epoch 6/100, Train Loss: 72.7312, Val Loss: 66.1998
# Epoch 7/100, Train Loss: 70.4095, Val Loss: 63.8972
# Epoch 8/100, Train Loss: 66.2875, Val Loss: 60.5802
# Epoch 9/100, Train Loss: 63.6915, Val Loss: 59.2426
# Epoch 10/100, Train Loss: 61.6661, Val Loss: 60.5702
# Epoch 11/100, Train Loss: 60.6617, Val Loss: 56.5041
# Epoch 12/100, Train Loss: 58.4769, Val Loss: 57.7951
# Epoch 13/100, Train Loss: 56.4391, Val Loss: 54.0397
# Epoch 14/100, Train Loss: 55.4928, Val Loss: 53.9983
# Epoch 15/100, Train Loss: 54.3370, Val Loss: 52.1867
# Epoch 16/100, Train Loss: 53.3600, Val Loss: 51.9885
# Epoch 17/100, Train Loss: 51.9503, Val Loss: 48.8097
# Epoch 18/100, Train Loss: 50.1963, Val Loss: 49.9104
# Epoch 19/100, Train Loss: 50.7707, Val Loss: 49.5036
# Epoch 20/100, Train Loss: 48.5729, Val Loss: 47.8208
# Epoch 21/100, Train Loss: 48.2618, Val Loss: 46.9501
# Epoch 22/100, Train Loss: 46.5317, Val Loss: 49.4130
# Epoch 23/100, Train Loss: 46.0813, Val Loss: 45.3107
# Epoch 24/100, Train Loss: 45.6877, Val Loss: 49.1798
# Epoch 25/100, Train Loss: 45.5679, Val Loss: 44.9503
# Epoch 26/100, Train Loss: 44.5778, Val Loss: 44.5386
# Epoch 27/100, Train Loss: 44.7101, Val Loss: 43.4818
# Epoch 28/100, Train Loss: 43.2900, Val Loss: 43.9717
# Epoch 29/100, Train Loss: 42.6834, Val Loss: 42.1468
# Epoch 30/100, Train Loss: 42.2802, Val Loss: 42.0702
# Epoch 31/100, Train Loss: 41.1375, Val Loss: 42.8451
# Epoch 32/100, Train Loss: 42.2111, Val Loss: 43.3919
# Epoch 33/100, Train Loss: 40.1730, Val Loss: 42.4529
# Epoch 34/100, Train Loss: 40.6780, Val Loss: 40.9059
# Epoch 35/100, Train Loss: 39.3990, Val Loss: 40.5833
# Epoch 36/100, Train Loss: 39.7084, Val Loss: 39.9472
# Epoch 37/100, Train Loss: 39.0404, Val Loss: 41.5956
# Epoch 38/100, Train Loss: 38.4312, Val Loss: 40.6034
# Epoch 39/100, Train Loss: 39.1328, Val Loss: 42.2626
# Epoch 40/100, Train Loss: 38.9417, Val Loss: 41.6156
# Epoch 41/100, Train Loss: 37.6879, Val Loss: 38.9737
# Epoch 42/100, Train Loss: 36.9055, Val Loss: 38.8622
# Epoch 43/100, Train Loss: 37.2447, Val Loss: 39.6158
# Epoch 44/100, Train Loss: 36.7441, Val Loss: 38.6733
# Epoch 45/100, Train Loss: 38.0009, Val Loss: 38.8970
# Epoch 46/100, Train Loss: 35.7134, Val Loss: 37.4069
# Epoch 47/100, Train Loss: 34.9972, Val Loss: 41.0141
# Epoch 48/100, Train Loss: 34.9353, Val Loss: 38.0413
# Epoch 49/100, Train Loss: 35.0846, Val Loss: 37.1623
# Epoch 50/100, Train Loss: 34.5793, Val Loss: 38.3148
# Epoch 51/100, Train Loss: 34.4397, Val Loss: 42.6321
# Epoch 52/100, Train Loss: 34.6990, Val Loss: 37.0242
# Epoch 53/100, Train Loss: 33.8467, Val Loss: 37.9483
# Epoch 54/100, Train Loss: 33.6051, Val Loss: 36.5851
# Epoch 55/100, Train Loss: 33.7440, Val Loss: 37.7696
# Epoch 56/100, Train Loss: 33.0809, Val Loss: 37.2440
# Epoch 57/100, Train Loss: 33.2175, Val Loss: 36.9525
# Epoch 58/100, Train Loss: 32.7125, Val Loss: 37.4176
# Epoch 59/100, Train Loss: 32.9538, Val Loss: 36.2007
# Epoch 60/100, Train Loss: 32.9220, Val Loss: 36.9139
# Epoch 61/100, Train Loss: 32.4157, Val Loss: 35.5818
# Epoch 62/100, Train Loss: 31.9148, Val Loss: 37.5918
# Epoch 63/100, Train Loss: 32.1220, Val Loss: 35.1184
# Epoch 64/100, Train Loss: 31.7644, Val Loss: 36.1179
# Epoch 65/100, Train Loss: 31.9293, Val Loss: 35.8089
# Epoch 66/100, Train Loss: 31.9512, Val Loss: 35.0607
# Epoch 67/100, Train Loss: 30.9454, Val Loss: 35.8807
# Epoch 68/100, Train Loss: 31.0483, Val Loss: 38.4661
# Epoch 69/100, Train Loss: 30.9580, Val Loss: 34.9695
# Epoch 70/100, Train Loss: 31.2457, Val Loss: 34.0340
# Epoch 71/100, Train Loss: 30.7083, Val Loss: 34.2906
# Epoch 72/100, Train Loss: 30.0782, Val Loss: 33.7970
# Epoch 73/100, Train Loss: 31.0053, Val Loss: 35.9450
# Epoch 74/100, Train Loss: 30.0275, Val Loss: 34.5132
# Epoch 75/100, Train Loss: 29.6626, Val Loss: 35.0570
# Epoch 76/100, Train Loss: 29.8491, Val Loss: 39.8451
# Epoch 77/100, Train Loss: 30.2975, Val Loss: 34.4402
# Epoch 78/100, Train Loss: 30.3063, Val Loss: 35.8416
# Epoch 79/100, Train Loss: 29.4241, Val Loss: 34.9512
# Epoch 80/100, Train Loss: 29.6692, Val Loss: 34.4434
# Epoch 81/100, Train Loss: 29.8940, Val Loss: 36.2043
# Epoch 82/100, Train Loss: 28.7194, Val Loss: 33.0234
# Epoch 83/100, Train Loss: 28.2151, Val Loss: 33.5092
# Epoch 84/100, Train Loss: 29.2102, Val Loss: 35.0259
# Epoch 85/100, Train Loss: 27.9659, Val Loss: 33.3928
# Epoch 86/100, Train Loss: 28.2509, Val Loss: 35.0943
# Epoch 87/100, Train Loss: 27.5922, Val Loss: 35.1359
# Epoch 88/100, Train Loss: 28.3294, Val Loss: 34.4913
# Epoch 89/100, Train Loss: 29.4286, Val Loss: 34.5575
# Epoch 90/100, Train Loss: 27.5632, Val Loss: 33.2196
# Epoch 91/100, Train Loss: 27.8776, Val Loss: 34.8037
# Epoch 92/100, Train Loss: 27.7565, Val Loss: 34.4217
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_9037/491623669.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 2 - MAE: 4.0476, RMSE: 5.7446
# Fold 3/5
# Epoch 1/100, Train Loss: 225.5532, Val Loss: 106.2064
# Epoch 2/100, Train Loss: 88.8285, Val Loss: 76.7293
# Epoch 3/100, Train Loss: 81.6490, Val Loss: 72.9416
# Epoch 4/100, Train Loss: 77.4852, Val Loss: 69.1592
# Epoch 5/100, Train Loss: 74.1404, Val Loss: 64.8570
# Epoch 6/100, Train Loss: 70.8504, Val Loss: 64.0993
# Epoch 7/100, Train Loss: 69.7482, Val Loss: 63.4515
# Epoch 8/100, Train Loss: 68.0769, Val Loss: 64.2161
# Epoch 9/100, Train Loss: 66.7258, Val Loss: 60.2579
# Epoch 10/100, Train Loss: 65.3575, Val Loss: 59.7694
# Epoch 11/100, Train Loss: 63.7579, Val Loss: 58.1671
# Epoch 12/100, Train Loss: 62.7250, Val Loss: 58.0074
# Epoch 13/100, Train Loss: 62.0285, Val Loss: 55.5864
# Epoch 14/100, Train Loss: 60.5873, Val Loss: 53.4243
# Epoch 15/100, Train Loss: 59.7533, Val Loss: 54.7077
# Epoch 16/100, Train Loss: 58.4859, Val Loss: 54.3627
# Epoch 17/100, Train Loss: 56.9678, Val Loss: 53.9278
# Epoch 18/100, Train Loss: 56.9008, Val Loss: 51.8304
# Epoch 19/100, Train Loss: 55.8693, Val Loss: 50.1335
# Epoch 20/100, Train Loss: 55.0606, Val Loss: 52.0112
# Epoch 21/100, Train Loss: 54.3531, Val Loss: 49.2018
# Epoch 22/100, Train Loss: 53.5576, Val Loss: 49.2282
# Epoch 23/100, Train Loss: 52.1096, Val Loss: 46.7819
# Epoch 24/100, Train Loss: 51.0260, Val Loss: 46.7056
# Epoch 25/100, Train Loss: 50.3798, Val Loss: 45.7908
# Epoch 26/100, Train Loss: 49.3262, Val Loss: 43.8980
# Epoch 27/100, Train Loss: 48.4665, Val Loss: 45.0021
# Epoch 28/100, Train Loss: 47.3740, Val Loss: 43.7702
# Epoch 29/100, Train Loss: 46.5508, Val Loss: 41.9996
# Epoch 30/100, Train Loss: 46.9229, Val Loss: 44.2209
# Epoch 31/100, Train Loss: 46.3437, Val Loss: 41.0675
# Epoch 32/100, Train Loss: 44.6886, Val Loss: 41.7544
# Epoch 33/100, Train Loss: 44.5962, Val Loss: 40.2392
# Epoch 34/100, Train Loss: 44.1896, Val Loss: 41.2349
# Epoch 35/100, Train Loss: 42.9392, Val Loss: 41.3526
# Epoch 36/100, Train Loss: 43.1715, Val Loss: 39.4042
# Epoch 37/100, Train Loss: 42.5564, Val Loss: 39.6131
# Epoch 38/100, Train Loss: 41.0092, Val Loss: 37.6412
# Epoch 39/100, Train Loss: 40.7480, Val Loss: 39.9991
# Epoch 40/100, Train Loss: 40.4028, Val Loss: 40.3479
# Epoch 41/100, Train Loss: 40.5867, Val Loss: 36.3108
# Epoch 42/100, Train Loss: 40.1015, Val Loss: 39.9287
# Epoch 43/100, Train Loss: 39.4825, Val Loss: 37.4191
# Epoch 44/100, Train Loss: 39.0718, Val Loss: 37.0894
# Epoch 45/100, Train Loss: 39.1830, Val Loss: 36.7055
# Epoch 46/100, Train Loss: 38.0044, Val Loss: 34.9823
# Epoch 47/100, Train Loss: 37.2856, Val Loss: 35.7551
# Epoch 48/100, Train Loss: 37.7282, Val Loss: 36.1429
# Epoch 49/100, Train Loss: 36.7336, Val Loss: 35.0692
# Epoch 50/100, Train Loss: 36.4547, Val Loss: 34.8134
# Epoch 51/100, Train Loss: 36.2601, Val Loss: 36.1087
# Epoch 52/100, Train Loss: 35.8216, Val Loss: 34.6199
# Epoch 53/100, Train Loss: 39.2758, Val Loss: 34.6792
# Epoch 54/100, Train Loss: 35.5107, Val Loss: 35.8450
# Epoch 55/100, Train Loss: 35.1821, Val Loss: 35.8350
# Epoch 56/100, Train Loss: 34.3204, Val Loss: 35.3949
# Epoch 57/100, Train Loss: 35.1080, Val Loss: 34.7158
# Epoch 58/100, Train Loss: 35.2922, Val Loss: 33.9266
# Epoch 59/100, Train Loss: 34.3099, Val Loss: 36.4672
# Epoch 60/100, Train Loss: 33.5973, Val Loss: 33.8837
# Epoch 61/100, Train Loss: 33.5818, Val Loss: 34.1581
# Epoch 62/100, Train Loss: 33.2126, Val Loss: 34.6255
# Epoch 63/100, Train Loss: 33.5185, Val Loss: 32.6643
# Epoch 64/100, Train Loss: 32.8554, Val Loss: 34.5563
# Epoch 65/100, Train Loss: 32.2247, Val Loss: 33.2042
# Epoch 66/100, Train Loss: 32.7577, Val Loss: 32.5889
# Epoch 67/100, Train Loss: 32.4557, Val Loss: 32.1644
# Epoch 68/100, Train Loss: 31.5318, Val Loss: 33.2776
# Epoch 69/100, Train Loss: 31.5370, Val Loss: 31.6678
# Epoch 70/100, Train Loss: 32.0818, Val Loss: 33.3258
# Epoch 71/100, Train Loss: 32.1725, Val Loss: 32.5853
# Epoch 72/100, Train Loss: 30.6881, Val Loss: 31.5690
# Epoch 73/100, Train Loss: 30.9471, Val Loss: 32.4943
# Epoch 74/100, Train Loss: 30.8388, Val Loss: 31.4103
# Epoch 75/100, Train Loss: 30.7976, Val Loss: 32.5489
# Epoch 76/100, Train Loss: 30.0122, Val Loss: 31.5132
# Epoch 77/100, Train Loss: 30.2202, Val Loss: 32.9588
# Epoch 78/100, Train Loss: 30.2260, Val Loss: 31.1891
# Epoch 79/100, Train Loss: 29.9482, Val Loss: 33.5038
# Epoch 80/100, Train Loss: 29.5251, Val Loss: 31.7689
# Epoch 81/100, Train Loss: 29.3461, Val Loss: 31.4184
# Epoch 82/100, Train Loss: 29.1922, Val Loss: 32.4049
# Epoch 83/100, Train Loss: 29.6129, Val Loss: 32.8694
# Epoch 84/100, Train Loss: 28.8241, Val Loss: 31.6950
# Epoch 85/100, Train Loss: 28.6832, Val Loss: 31.9643
# Epoch 86/100, Train Loss: 29.0686, Val Loss: 33.2734
# Epoch 87/100, Train Loss: 28.6367, Val Loss: 31.2382
# Epoch 88/100, Train Loss: 28.9551, Val Loss: 33.9123
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_9037/491623669.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 3 - MAE: 4.0383, RMSE: 5.5782
# Fold 4/5
# Epoch 1/100, Train Loss: 231.9961, Val Loss: 117.7923
# Epoch 2/100, Train Loss: 90.6509, Val Loss: 79.0523
# Epoch 3/100, Train Loss: 80.2593, Val Loss: 76.0482
# Epoch 4/100, Train Loss: 76.4276, Val Loss: 71.9402
# Epoch 5/100, Train Loss: 74.1681, Val Loss: 72.2468
# Epoch 6/100, Train Loss: 70.8315, Val Loss: 64.2921
# Epoch 7/100, Train Loss: 68.8386, Val Loss: 63.8791
# Epoch 8/100, Train Loss: 67.1818, Val Loss: 63.6683
# Epoch 9/100, Train Loss: 65.6823, Val Loss: 61.2453
# Epoch 10/100, Train Loss: 64.1107, Val Loss: 63.7638
# Epoch 11/100, Train Loss: 63.4970, Val Loss: 57.9138
# Epoch 12/100, Train Loss: 62.0396, Val Loss: 56.4935
# Epoch 13/100, Train Loss: 60.9565, Val Loss: 57.4387
# Epoch 14/100, Train Loss: 59.7563, Val Loss: 61.0478
# Epoch 15/100, Train Loss: 58.1763, Val Loss: 58.0753
# Epoch 16/100, Train Loss: 56.7030, Val Loss: 51.5756
# Epoch 17/100, Train Loss: 56.5956, Val Loss: 54.3311
# Epoch 18/100, Train Loss: 55.1169, Val Loss: 49.5531
# Epoch 19/100, Train Loss: 53.5388, Val Loss: 50.5155
# Epoch 20/100, Train Loss: 52.1965, Val Loss: 49.1458
# Epoch 21/100, Train Loss: 51.0266, Val Loss: 49.9974
# Epoch 22/100, Train Loss: 50.4557, Val Loss: 47.6740
# Epoch 23/100, Train Loss: 50.2401, Val Loss: 47.0311
# Epoch 24/100, Train Loss: 48.8379, Val Loss: 48.0256
# Epoch 25/100, Train Loss: 47.6820, Val Loss: 44.8085
# Epoch 26/100, Train Loss: 46.9739, Val Loss: 44.1038
# Epoch 27/100, Train Loss: 46.4762, Val Loss: 42.1451
# Epoch 28/100, Train Loss: 44.9937, Val Loss: 42.2331
# Epoch 29/100, Train Loss: 44.8616, Val Loss: 42.5103
# Epoch 30/100, Train Loss: 44.8041, Val Loss: 42.5375
# Epoch 31/100, Train Loss: 43.7525, Val Loss: 41.9976
# Epoch 32/100, Train Loss: 43.1864, Val Loss: 40.5887
# Epoch 33/100, Train Loss: 42.3220, Val Loss: 41.7967
# Epoch 34/100, Train Loss: 42.6472, Val Loss: 39.6046
# Epoch 35/100, Train Loss: 41.4312, Val Loss: 37.9701
# Epoch 36/100, Train Loss: 41.4527, Val Loss: 38.1636
# Epoch 37/100, Train Loss: 40.9739, Val Loss: 40.7382
# Epoch 38/100, Train Loss: 39.9051, Val Loss: 37.3778
# Epoch 39/100, Train Loss: 39.7832, Val Loss: 37.3567
# Epoch 40/100, Train Loss: 39.2849, Val Loss: 39.0834
# Epoch 41/100, Train Loss: 38.3675, Val Loss: 35.6567
# Epoch 42/100, Train Loss: 38.4106, Val Loss: 35.3407
# Epoch 43/100, Train Loss: 38.2121, Val Loss: 35.4490
# Epoch 44/100, Train Loss: 36.8709, Val Loss: 35.2393
# Epoch 45/100, Train Loss: 37.8827, Val Loss: 35.7519
# Epoch 46/100, Train Loss: 36.1768, Val Loss: 34.7435
# Epoch 47/100, Train Loss: 36.4303, Val Loss: 34.1893
# Epoch 48/100, Train Loss: 35.2272, Val Loss: 33.9316
# Epoch 49/100, Train Loss: 35.4709, Val Loss: 34.0147
# Epoch 50/100, Train Loss: 34.8380, Val Loss: 34.4860
# Epoch 51/100, Train Loss: 38.1450, Val Loss: 36.7828
# Epoch 52/100, Train Loss: 34.4704, Val Loss: 32.5808
# Epoch 53/100, Train Loss: 34.0408, Val Loss: 34.9061
# Epoch 54/100, Train Loss: 33.4419, Val Loss: 32.9087
# Epoch 55/100, Train Loss: 34.8544, Val Loss: 32.4512
# Epoch 56/100, Train Loss: 33.6855, Val Loss: 32.2176
# Epoch 57/100, Train Loss: 32.8474, Val Loss: 31.7894
# Epoch 58/100, Train Loss: 32.7764, Val Loss: 32.2259
# Epoch 59/100, Train Loss: 32.9543, Val Loss: 34.2835
# Epoch 60/100, Train Loss: 32.8778, Val Loss: 32.7241
# Epoch 61/100, Train Loss: 32.9056, Val Loss: 31.6839
# Epoch 62/100, Train Loss: 31.9115, Val Loss: 34.3888
# Epoch 63/100, Train Loss: 31.9460, Val Loss: 30.5509
# Epoch 64/100, Train Loss: 31.5436, Val Loss: 31.0612
# Epoch 65/100, Train Loss: 31.5766, Val Loss: 32.2166
# Epoch 66/100, Train Loss: 31.4118, Val Loss: 30.6264
# Epoch 67/100, Train Loss: 31.3968, Val Loss: 30.9087
# Epoch 68/100, Train Loss: 30.3815, Val Loss: 32.6512
# Epoch 69/100, Train Loss: 30.1678, Val Loss: 31.2768
# Epoch 70/100, Train Loss: 30.5855, Val Loss: 33.2689
# Epoch 71/100, Train Loss: 32.7972, Val Loss: 31.2757
# Epoch 72/100, Train Loss: 29.9638, Val Loss: 29.7177
# Epoch 73/100, Train Loss: 29.2877, Val Loss: 32.1003
# Epoch 74/100, Train Loss: 29.8167, Val Loss: 29.5419
# Epoch 75/100, Train Loss: 29.3121, Val Loss: 30.3048
# Epoch 76/100, Train Loss: 29.5628, Val Loss: 31.1480
# Epoch 77/100, Train Loss: 29.7590, Val Loss: 30.7554
# Epoch 78/100, Train Loss: 29.1297, Val Loss: 30.7457
# Epoch 79/100, Train Loss: 28.8886, Val Loss: 29.6593
# Epoch 80/100, Train Loss: 29.9426, Val Loss: 29.9132
# Epoch 81/100, Train Loss: 28.5212, Val Loss: 31.1704
# Epoch 82/100, Train Loss: 28.9036, Val Loss: 29.7935
# Epoch 83/100, Train Loss: 28.3529, Val Loss: 31.6115
# Epoch 84/100, Train Loss: 29.2758, Val Loss: 30.7198
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_9037/491623669.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 4 - MAE: 3.9037, RMSE: 5.4365
# Fold 5/5
# Epoch 1/100, Train Loss: 209.0782, Val Loss: 113.4483
# Epoch 2/100, Train Loss: 82.7210, Val Loss: 94.5620
# Epoch 3/100, Train Loss: 75.7973, Val Loss: 89.1939
# Epoch 4/100, Train Loss: 71.1389, Val Loss: 87.8052
# Epoch 5/100, Train Loss: 67.7931, Val Loss: 81.5930
# Epoch 6/100, Train Loss: 65.3996, Val Loss: 78.5629
# Epoch 7/100, Train Loss: 63.8311, Val Loss: 77.5699
# Epoch 8/100, Train Loss: 62.1811, Val Loss: 77.4427
# Epoch 9/100, Train Loss: 60.8041, Val Loss: 75.2093
# Epoch 10/100, Train Loss: 60.2775, Val Loss: 74.6121
# Epoch 11/100, Train Loss: 59.4127, Val Loss: 73.0144
# Epoch 12/100, Train Loss: 58.1067, Val Loss: 72.1044
# Epoch 13/100, Train Loss: 56.8237, Val Loss: 69.6289
# Epoch 14/100, Train Loss: 55.7573, Val Loss: 68.0548
# Epoch 15/100, Train Loss: 54.7421, Val Loss: 67.9063
# Epoch 16/100, Train Loss: 54.0421, Val Loss: 67.3088
# Epoch 17/100, Train Loss: 53.1734, Val Loss: 65.8806
# Epoch 18/100, Train Loss: 52.0426, Val Loss: 65.6389
# Epoch 19/100, Train Loss: 51.1753, Val Loss: 65.9770
# Epoch 20/100, Train Loss: 51.0680, Val Loss: 69.1195
# Epoch 21/100, Train Loss: 50.0103, Val Loss: 62.8157
# Epoch 22/100, Train Loss: 48.8036, Val Loss: 60.6969
# Epoch 23/100, Train Loss: 48.2210, Val Loss: 62.4310
# Epoch 24/100, Train Loss: 47.5565, Val Loss: 60.3098
# Epoch 25/100, Train Loss: 45.1045, Val Loss: 58.4302
# Epoch 26/100, Train Loss: 46.0216, Val Loss: 57.1983
# Epoch 27/100, Train Loss: 44.7635, Val Loss: 56.5098
# Epoch 28/100, Train Loss: 43.9227, Val Loss: 56.0393
# Epoch 29/100, Train Loss: 42.8697, Val Loss: 55.8792
# Epoch 30/100, Train Loss: 43.1197, Val Loss: 56.7315
# Epoch 31/100, Train Loss: 41.9422, Val Loss: 55.1620
# Epoch 32/100, Train Loss: 41.1407, Val Loss: 57.8679
# Epoch 33/100, Train Loss: 41.2224, Val Loss: 53.6658
# Epoch 34/100, Train Loss: 39.8728, Val Loss: 55.2693
# Epoch 35/100, Train Loss: 39.7792, Val Loss: 53.4195
# Epoch 36/100, Train Loss: 39.1381, Val Loss: 53.4803
# Epoch 37/100, Train Loss: 39.3686, Val Loss: 51.0820
# Epoch 38/100, Train Loss: 38.1789, Val Loss: 49.7462
# Epoch 39/100, Train Loss: 37.3691, Val Loss: 49.7380
# Epoch 40/100, Train Loss: 37.1163, Val Loss: 48.6241
# Epoch 41/100, Train Loss: 37.3196, Val Loss: 50.2193
# Epoch 42/100, Train Loss: 36.0641, Val Loss: 49.8752
# Epoch 43/100, Train Loss: 35.8809, Val Loss: 48.6992
# Epoch 44/100, Train Loss: 35.1732, Val Loss: 47.6480
# Epoch 45/100, Train Loss: 34.9258, Val Loss: 51.0927
# Epoch 46/100, Train Loss: 35.1769, Val Loss: 47.3382
# Epoch 47/100, Train Loss: 34.5292, Val Loss: 47.3976
# Epoch 48/100, Train Loss: 33.8912, Val Loss: 47.5855
# Epoch 49/100, Train Loss: 33.3374, Val Loss: 46.5328
# Epoch 50/100, Train Loss: 33.6007, Val Loss: 46.8362
# Epoch 51/100, Train Loss: 32.6966, Val Loss: 47.2101
# Epoch 52/100, Train Loss: 33.2436, Val Loss: 45.0567
# Epoch 53/100, Train Loss: 32.9730, Val Loss: 44.7172
# Epoch 54/100, Train Loss: 32.1310, Val Loss: 45.1826
# Epoch 55/100, Train Loss: 31.7952, Val Loss: 44.0468
# Epoch 56/100, Train Loss: 31.7446, Val Loss: 44.0455
# Epoch 57/100, Train Loss: 31.7152, Val Loss: 43.3604
# Epoch 58/100, Train Loss: 31.0210, Val Loss: 44.2822
# Epoch 59/100, Train Loss: 30.6687, Val Loss: 43.4915
# Epoch 60/100, Train Loss: 30.7462, Val Loss: 42.6048
# Epoch 61/100, Train Loss: 30.3589, Val Loss: 43.3701
# Epoch 62/100, Train Loss: 30.3150, Val Loss: 42.5469
# Epoch 63/100, Train Loss: 30.0207, Val Loss: 42.3508
# Epoch 64/100, Train Loss: 29.3673, Val Loss: 41.8802
# Epoch 65/100, Train Loss: 29.6255, Val Loss: 42.8579
# Epoch 66/100, Train Loss: 29.6067, Val Loss: 43.8257
# Epoch 67/100, Train Loss: 28.9824, Val Loss: 47.1109
# Epoch 68/100, Train Loss: 29.0621, Val Loss: 52.4088
# Epoch 69/100, Train Loss: 28.5152, Val Loss: 41.4898
# Epoch 70/100, Train Loss: 28.9244, Val Loss: 42.5118
# Epoch 71/100, Train Loss: 28.4439, Val Loss: 42.1088
# Epoch 72/100, Train Loss: 28.1077, Val Loss: 41.4188
# Epoch 73/100, Train Loss: 28.1089, Val Loss: 43.7258
# Epoch 74/100, Train Loss: 28.4203, Val Loss: 41.7208
# Epoch 75/100, Train Loss: 28.1380, Val Loss: 41.4126
# Epoch 76/100, Train Loss: 27.4190, Val Loss: 41.0581
# Epoch 77/100, Train Loss: 27.7503, Val Loss: 41.0305
# Epoch 78/100, Train Loss: 27.7735, Val Loss: 43.0165
# Epoch 79/100, Train Loss: 27.3460, Val Loss: 42.8932
# Epoch 80/100, Train Loss: 27.0887, Val Loss: 40.5439
# Epoch 81/100, Train Loss: 26.9889, Val Loss: 41.3627
# Epoch 82/100, Train Loss: 27.0995, Val Loss: 41.6133
# Epoch 83/100, Train Loss: 26.7520, Val Loss: 41.1752
# Epoch 84/100, Train Loss: 26.6468, Val Loss: 42.8691
# Epoch 85/100, Train Loss: 26.4806, Val Loss: 41.7742
# Epoch 86/100, Train Loss: 26.1128, Val Loss: 41.4524
# Epoch 87/100, Train Loss: 26.1523, Val Loss: 41.8063
# Epoch 88/100, Train Loss: 26.1367, Val Loss: 40.2933
# Epoch 89/100, Train Loss: 25.8513, Val Loss: 40.3500
# Epoch 90/100, Train Loss: 25.4874, Val Loss: 40.0234
# Epoch 91/100, Train Loss: 25.2706, Val Loss: 40.0539
# Epoch 92/100, Train Loss: 25.5031, Val Loss: 42.2707
# Epoch 93/100, Train Loss: 25.6120, Val Loss: 40.3593
# Epoch 94/100, Train Loss: 25.2892, Val Loss: 40.0769
# Epoch 95/100, Train Loss: 25.0260, Val Loss: 40.0921
# Epoch 96/100, Train Loss: 25.0813, Val Loss: 41.7404
# Epoch 97/100, Train Loss: 25.4924, Val Loss: 41.4537
# Epoch 98/100, Train Loss: 24.8282, Val Loss: 41.2703
# Epoch 99/100, Train Loss: 25.1188, Val Loss: 40.9348
# Epoch 100/100, Train Loss: 24.8726, Val Loss: 40.5491
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_9037/491623669.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold}.pth'))
# Fold 5 - MAE: 4.1538, RMSE: 6.3286
# Average Train Loss: 28.2179
# Average Val Loss: 33.8922
# Average MAE: 4.0151
# Average RMSE: 5.6905
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
