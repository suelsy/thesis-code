# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_absolute_error, mean_squared_error
import random

# 设置随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# 在代码的开头设置随机种子
set_seed(42)

# 读取数据
data = pd.read_csv('final_50_all.csv')

# 特征工程
data['hour'] = pd.to_datetime(data['hour'])
data['year'] = data['hour'].dt.year
data['month'] = data['hour'].dt.month
data['day'] = data['hour'].dt.day
data['hour_of_day'] = data['hour'].dt.hour
data['weekday'] = data['hour'].dt.weekday

data['hour_sin'] = np.sin(2 * np.pi * data['hour_of_day'] / 24)
data['hour_cos'] = np.cos(2 * np.pi * data['hour_of_day'] / 24)
data['weekday_sin'] = np.sin(2 * np.pi * data['weekday'] / 7)
data['weekday_cos'] = np.cos(2 * np.pi * data['weekday'] / 7)
data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

# 数值特征缩放
num_features = ['temperature_2m (°C)', 'apparent_temperature (°C)', 'rain (mm)', 'wind_speed_100m (km/h)']
scaler = MinMaxScaler()
data[num_features] = scaler.fit_transform(data[num_features])

data.drop(['month','day','hour', 'hour_of_day', 'weekday'], axis=1, inplace=True)

# 提取最终特征和目标
features = num_features + ['hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos','month_sin','month_cos'] 
target = 'ride_count'

X = data[features].values
y = data[target].values

# 数据标准化
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

def create_sequences(data, target, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(target[i + sequence_length])
    return np.array(X), np.array(y)

# 设置序列长度
sequence_length = 24  # 例如使用过去24小时的数据预测
X, y = create_sequences(X, y, sequence_length)

# 使用 KFold 进行交叉验证
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# 初始化存储结果的列表
test_losses = []
maes = []
rmses = []

# 交叉验证过程
for fold, (train_index, val_index) in enumerate(kf.split(X)):
    print(f"\nFold {fold + 1}")

    # 分割数据
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # 转换为张量
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

    # 数据加载器
    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=32)

    # GRU 模型定义
    class GRUModel(nn.Module):
        def __init__(self, input_size, hidden_size, output_size, dropout=0.2):
            super(GRUModel, self).__init__()
            self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
            self.fc = nn.Linear(hidden_size, output_size)
            self.dropout = nn.Dropout(dropout)
        
        def forward(self, x):
            out, _ = self.gru(x)
            out = self.dropout(out[:, -1, :])
            out = self.fc(out)
            return out

    # 模型实例化
    input_size = len(features)
    hidden_size = 64
    output_size = 1
    model = GRUModel(input_size, hidden_size, output_size)

    # 损失函数和优化器
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # 训练与验证
    patience = 10
    best_val_loss = float('inf')
    early_stop_counter = 0
    epochs = 100

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = model(X_batch).squeeze()
            loss = criterion(y_pred, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)

        # 验证阶段
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                y_pred = model(X_batch).squeeze()
                loss = criterion(y_pred, y_batch)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # 早停机制
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            torch.save(model.state_dict(), f'best_model_fold{fold+1}.pth')  # 保存最佳模型
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print("Early stopping triggered")
            break

    # 测试集评估
    model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
    model.eval()
    val_loss = 0
    y_preds = []
    y_trues = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            y_pred = model(X_batch).squeeze()
            y_preds.extend(y_pred.squeeze().tolist())
            y_trues.extend(y_batch.tolist())
            loss = criterion(y_pred.squeeze(), y_batch)
            val_loss += loss.item()

    val_loss /= len(val_loader)
    mae = mean_absolute_error(y_trues, y_preds)
    rmse = mean_squared_error(y_trues, y_preds, squared=False)

    test_losses.append(val_loss)
    maes.append(mae)
    rmses.append(rmse)

    print(f"Fold {fold+1} - Val Loss: {val_loss:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# 输出所有折的平均性能
print(f"\nAverage Val Loss: {np.mean(test_losses):.4f}")
print(f"Average MAE: {np.mean(maes):.4f}")
print(f"Average RMSE: {np.mean(rmses):.4f}")
# Out:
# Fold 1
# Epoch 1/100, Train Loss: 241.6660, Val Loss: 204.0920
# Epoch 2/100, Train Loss: 178.1141, Val Loss: 96.8517
# Epoch 3/100, Train Loss: 91.8842, Val Loss: 81.8310
# Epoch 4/100, Train Loss: 85.1428, Val Loss: 78.5957
# Epoch 5/100, Train Loss: 81.1591, Val Loss: 74.5196
# Epoch 6/100, Train Loss: 77.0691, Val Loss: 76.9524
# Epoch 7/100, Train Loss: 75.0562, Val Loss: 68.8411
# Epoch 8/100, Train Loss: 73.6238, Val Loss: 67.9628
# Epoch 9/100, Train Loss: 72.1286, Val Loss: 67.7098
# Epoch 10/100, Train Loss: 71.4930, Val Loss: 69.6343
# Epoch 11/100, Train Loss: 71.0846, Val Loss: 72.0692
# Epoch 12/100, Train Loss: 71.0206, Val Loss: 66.2789
# Epoch 13/100, Train Loss: 69.6638, Val Loss: 69.2332
# Epoch 14/100, Train Loss: 69.3480, Val Loss: 65.3721
# Epoch 15/100, Train Loss: 69.1656, Val Loss: 67.7241
# Epoch 16/100, Train Loss: 68.3702, Val Loss: 66.1866
# Epoch 17/100, Train Loss: 68.1723, Val Loss: 64.1679
# Epoch 18/100, Train Loss: 68.2322, Val Loss: 64.2855
# Epoch 19/100, Train Loss: 67.3804, Val Loss: 65.1727
# Epoch 20/100, Train Loss: 66.9658, Val Loss: 64.3766
# Epoch 21/100, Train Loss: 66.3250, Val Loss: 63.0828
# Epoch 22/100, Train Loss: 65.8629, Val Loss: 63.1489
# Epoch 23/100, Train Loss: 65.6585, Val Loss: 67.8333
# Epoch 24/100, Train Loss: 65.2064, Val Loss: 67.2840
# Epoch 25/100, Train Loss: 65.2235, Val Loss: 64.4284
# Epoch 26/100, Train Loss: 64.5360, Val Loss: 62.7821
# Epoch 27/100, Train Loss: 63.6882, Val Loss: 62.5115
# Epoch 28/100, Train Loss: 63.3292, Val Loss: 62.5897
# Epoch 29/100, Train Loss: 62.8681, Val Loss: 64.6729
# Epoch 30/100, Train Loss: 62.3609, Val Loss: 60.1913
# Epoch 31/100, Train Loss: 61.9162, Val Loss: 59.9193
# Epoch 32/100, Train Loss: 61.5437, Val Loss: 59.3390
# Epoch 33/100, Train Loss: 60.4805, Val Loss: 59.1839
# Epoch 34/100, Train Loss: 60.2996, Val Loss: 59.1875
# Epoch 35/100, Train Loss: 59.4093, Val Loss: 60.2275
# Epoch 36/100, Train Loss: 59.0738, Val Loss: 60.2705
# Epoch 37/100, Train Loss: 58.4501, Val Loss: 59.6235
# Epoch 38/100, Train Loss: 58.0075, Val Loss: 56.7165
# Epoch 39/100, Train Loss: 57.7092, Val Loss: 58.9741
# Epoch 40/100, Train Loss: 57.4896, Val Loss: 56.9750
# Epoch 41/100, Train Loss: 56.9903, Val Loss: 57.2340
# Epoch 42/100, Train Loss: 56.9031, Val Loss: 56.7221
# Epoch 43/100, Train Loss: 55.6251, Val Loss: 55.5669
# Epoch 44/100, Train Loss: 55.2293, Val Loss: 54.6166
# Epoch 45/100, Train Loss: 54.3860, Val Loss: 55.6133
# Epoch 46/100, Train Loss: 53.9579, Val Loss: 52.4592
# Epoch 47/100, Train Loss: 53.4291, Val Loss: 53.1390
# Epoch 48/100, Train Loss: 52.9948, Val Loss: 52.7510
# Epoch 49/100, Train Loss: 52.6161, Val Loss: 52.0462
# Epoch 50/100, Train Loss: 51.6822, Val Loss: 50.1721
# Epoch 51/100, Train Loss: 51.0992, Val Loss: 48.9325
# Epoch 52/100, Train Loss: 51.4433, Val Loss: 50.4517
# Epoch 53/100, Train Loss: 50.1862, Val Loss: 54.6076
# Epoch 54/100, Train Loss: 49.2411, Val Loss: 47.6731
# Epoch 55/100, Train Loss: 49.4160, Val Loss: 48.6764
# Epoch 56/100, Train Loss: 48.4765, Val Loss: 48.4032
# Epoch 57/100, Train Loss: 47.8741, Val Loss: 47.1444
# Epoch 58/100, Train Loss: 47.2412, Val Loss: 47.0016
# Epoch 59/100, Train Loss: 46.2127, Val Loss: 46.0154
# Epoch 60/100, Train Loss: 46.0748, Val Loss: 46.6868
# Epoch 61/100, Train Loss: 45.7862, Val Loss: 47.0182
# Epoch 62/100, Train Loss: 44.5988, Val Loss: 45.6737
# Epoch 63/100, Train Loss: 44.9209, Val Loss: 43.7128
# Epoch 64/100, Train Loss: 43.6804, Val Loss: 44.6017
# Epoch 65/100, Train Loss: 44.0590, Val Loss: 44.8987
# Epoch 66/100, Train Loss: 43.1522, Val Loss: 46.0575
# Epoch 67/100, Train Loss: 42.8909, Val Loss: 44.1570
# Epoch 68/100, Train Loss: 42.5800, Val Loss: 43.6114
# Epoch 69/100, Train Loss: 41.9918, Val Loss: 43.8380
# Epoch 70/100, Train Loss: 41.3902, Val Loss: 42.3730
# Epoch 71/100, Train Loss: 41.2866, Val Loss: 43.8730
# Epoch 72/100, Train Loss: 41.0577, Val Loss: 43.4488
# Epoch 73/100, Train Loss: 40.2650, Val Loss: 42.2169
# Epoch 74/100, Train Loss: 39.9209, Val Loss: 43.8343
# Epoch 75/100, Train Loss: 39.5572, Val Loss: 42.1082
# Epoch 76/100, Train Loss: 40.0478, Val Loss: 42.3607
# Epoch 77/100, Train Loss: 39.2157, Val Loss: 42.1153
# Epoch 78/100, Train Loss: 39.2049, Val Loss: 41.9928
# Epoch 79/100, Train Loss: 38.2834, Val Loss: 40.7829
# Epoch 80/100, Train Loss: 38.1375, Val Loss: 40.7154
# Epoch 81/100, Train Loss: 37.7573, Val Loss: 40.2664
# Epoch 82/100, Train Loss: 37.5659, Val Loss: 40.0905
# Epoch 83/100, Train Loss: 37.8745, Val Loss: 39.4137
# Epoch 84/100, Train Loss: 36.9966, Val Loss: 39.6003
# Epoch 85/100, Train Loss: 36.7396, Val Loss: 39.7750
# Epoch 86/100, Train Loss: 37.9087, Val Loss: 39.9838
# Epoch 87/100, Train Loss: 36.2414, Val Loss: 40.2126
# Epoch 88/100, Train Loss: 35.8048, Val Loss: 38.4529
# Epoch 89/100, Train Loss: 36.7659, Val Loss: 41.5716
# Epoch 90/100, Train Loss: 36.2413, Val Loss: 39.6640
# Epoch 91/100, Train Loss: 34.8795, Val Loss: 38.8858
# Epoch 92/100, Train Loss: 34.9645, Val Loss: 37.7528
# Epoch 93/100, Train Loss: 34.3492, Val Loss: 38.7366
# Epoch 94/100, Train Loss: 34.4246, Val Loss: 39.1520
# Epoch 95/100, Train Loss: 34.3679, Val Loss: 38.4662
# Epoch 96/100, Train Loss: 34.8624, Val Loss: 38.0138
# Epoch 97/100, Train Loss: 34.1687, Val Loss: 39.0474
# Epoch 98/100, Train Loss: 34.4465, Val Loss: 39.0891
# Epoch 99/100, Train Loss: 34.2251, Val Loss: 38.5171
# Epoch 100/100, Train Loss: 33.0305, Val Loss: 38.6121
# Fold 1 - Val Loss: 37.7528, MAE: 4.3601, RMSE: 6.1442
#
# Fold 2
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_73578/3412344545.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch 1/100, Train Loss: 239.9326, Val Loss: 211.1173
# Epoch 2/100, Train Loss: 128.4493, Val Loss: 96.8173
# Epoch 3/100, Train Loss: 89.3811, Val Loss: 89.6416
# Epoch 4/100, Train Loss: 83.0593, Val Loss: 83.0211
# Epoch 5/100, Train Loss: 80.5126, Val Loss: 80.5255
# Epoch 6/100, Train Loss: 77.9772, Val Loss: 80.4410
# Epoch 7/100, Train Loss: 76.5757, Val Loss: 84.4639
# Epoch 8/100, Train Loss: 74.9072, Val Loss: 76.2546
# Epoch 9/100, Train Loss: 74.4914, Val Loss: 76.7661
# Epoch 10/100, Train Loss: 72.9230, Val Loss: 73.2208
# Epoch 11/100, Train Loss: 72.3732, Val Loss: 72.1361
# Epoch 12/100, Train Loss: 71.2725, Val Loss: 73.3580
# Epoch 13/100, Train Loss: 70.5695, Val Loss: 75.6754
# Epoch 14/100, Train Loss: 70.4493, Val Loss: 73.1658
# Epoch 15/100, Train Loss: 70.0729, Val Loss: 70.6344
# Epoch 16/100, Train Loss: 68.6346, Val Loss: 69.6905
# Epoch 17/100, Train Loss: 68.5712, Val Loss: 71.4723
# Epoch 18/100, Train Loss: 68.8897, Val Loss: 70.8749
# Epoch 19/100, Train Loss: 67.7622, Val Loss: 69.2489
# Epoch 20/100, Train Loss: 68.0464, Val Loss: 68.6955
# Epoch 21/100, Train Loss: 68.1284, Val Loss: 69.2526
# Epoch 22/100, Train Loss: 67.6357, Val Loss: 68.8711
# Epoch 23/100, Train Loss: 66.6261, Val Loss: 67.6798
# Epoch 24/100, Train Loss: 66.4478, Val Loss: 69.0138
# Epoch 25/100, Train Loss: 66.0430, Val Loss: 70.1701
# Epoch 26/100, Train Loss: 65.6303, Val Loss: 67.0224
# Epoch 27/100, Train Loss: 65.2451, Val Loss: 66.6320
# Epoch 28/100, Train Loss: 65.0256, Val Loss: 66.3645
# Epoch 29/100, Train Loss: 64.7154, Val Loss: 66.0302
# Epoch 30/100, Train Loss: 63.4147, Val Loss: 68.1091
# Epoch 31/100, Train Loss: 63.5363, Val Loss: 67.9347
# Epoch 32/100, Train Loss: 62.8383, Val Loss: 64.7212
# Epoch 33/100, Train Loss: 62.8851, Val Loss: 68.9386
# Epoch 34/100, Train Loss: 62.2985, Val Loss: 63.3346
# Epoch 35/100, Train Loss: 60.9540, Val Loss: 64.2245
# Epoch 36/100, Train Loss: 61.3662, Val Loss: 62.9152
# Epoch 37/100, Train Loss: 60.9019, Val Loss: 63.0514
# Epoch 38/100, Train Loss: 60.2717, Val Loss: 63.6103
# Epoch 39/100, Train Loss: 59.8543, Val Loss: 62.8998
# Epoch 40/100, Train Loss: 59.7999, Val Loss: 64.5196
# Epoch 41/100, Train Loss: 59.2099, Val Loss: 64.2589
# Epoch 42/100, Train Loss: 58.7035, Val Loss: 60.8485
# Epoch 43/100, Train Loss: 57.7336, Val Loss: 60.5375
# Epoch 44/100, Train Loss: 57.4643, Val Loss: 61.1884
# Epoch 45/100, Train Loss: 57.0894, Val Loss: 62.8757
# Epoch 46/100, Train Loss: 56.4072, Val Loss: 61.7528
# Epoch 47/100, Train Loss: 56.4718, Val Loss: 59.1254
# Epoch 48/100, Train Loss: 56.1981, Val Loss: 60.0783
# Epoch 49/100, Train Loss: 55.4457, Val Loss: 58.6524
# Epoch 50/100, Train Loss: 54.4377, Val Loss: 62.5884
# Epoch 51/100, Train Loss: 54.2585, Val Loss: 58.1215
# Epoch 52/100, Train Loss: 54.5668, Val Loss: 60.2642
# Epoch 53/100, Train Loss: 52.7184, Val Loss: 56.4304
# Epoch 54/100, Train Loss: 51.9235, Val Loss: 57.2079
# Epoch 55/100, Train Loss: 52.8809, Val Loss: 56.4302
# Epoch 56/100, Train Loss: 52.9903, Val Loss: 56.4402
# Epoch 57/100, Train Loss: 50.5049, Val Loss: 56.8435
# Epoch 58/100, Train Loss: 49.7457, Val Loss: 55.1028
# Epoch 59/100, Train Loss: 50.1563, Val Loss: 55.5351
# Epoch 60/100, Train Loss: 48.7921, Val Loss: 53.8947
# Epoch 61/100, Train Loss: 48.9807, Val Loss: 51.4752
# Epoch 62/100, Train Loss: 48.4905, Val Loss: 53.4279
# Epoch 63/100, Train Loss: 47.5659, Val Loss: 51.6838
# Epoch 64/100, Train Loss: 47.4498, Val Loss: 52.0128
# Epoch 65/100, Train Loss: 46.8071, Val Loss: 52.5181
# Epoch 66/100, Train Loss: 46.7421, Val Loss: 51.4618
# Epoch 67/100, Train Loss: 45.5940, Val Loss: 50.2124
# Epoch 68/100, Train Loss: 45.8589, Val Loss: 50.9420
# Epoch 69/100, Train Loss: 45.7700, Val Loss: 50.5824
# Epoch 70/100, Train Loss: 45.2760, Val Loss: 50.3622
# Epoch 71/100, Train Loss: 43.9053, Val Loss: 48.9102
# Epoch 72/100, Train Loss: 44.1517, Val Loss: 48.5450
# Epoch 73/100, Train Loss: 43.7952, Val Loss: 47.2983
# Epoch 74/100, Train Loss: 43.4591, Val Loss: 49.8495
# Epoch 75/100, Train Loss: 43.1425, Val Loss: 48.5248
# Epoch 76/100, Train Loss: 42.5001, Val Loss: 47.4949
# Epoch 77/100, Train Loss: 42.3848, Val Loss: 47.5783
# Epoch 78/100, Train Loss: 42.1463, Val Loss: 47.7908
# Epoch 79/100, Train Loss: 41.9767, Val Loss: 48.6659
# Epoch 80/100, Train Loss: 41.9193, Val Loss: 48.9776
# Epoch 81/100, Train Loss: 41.7274, Val Loss: 45.7460
# Epoch 82/100, Train Loss: 40.5765, Val Loss: 47.1531
# Epoch 83/100, Train Loss: 41.3444, Val Loss: 47.3317
# Epoch 84/100, Train Loss: 41.1017, Val Loss: 46.2947
# Epoch 85/100, Train Loss: 39.9035, Val Loss: 44.8295
# Epoch 86/100, Train Loss: 39.6877, Val Loss: 49.3610
# Epoch 87/100, Train Loss: 39.8266, Val Loss: 45.5880
# Epoch 88/100, Train Loss: 39.9208, Val Loss: 46.0703
# Epoch 89/100, Train Loss: 38.9099, Val Loss: 46.6715
# Epoch 90/100, Train Loss: 38.7246, Val Loss: 46.2462
# Epoch 91/100, Train Loss: 38.8876, Val Loss: 45.5773
# Epoch 92/100, Train Loss: 38.0400, Val Loss: 45.5271
# Epoch 93/100, Train Loss: 38.7283, Val Loss: 44.3640
# Epoch 94/100, Train Loss: 37.5034, Val Loss: 45.7845
# Epoch 95/100, Train Loss: 38.5631, Val Loss: 44.0508
# Epoch 96/100, Train Loss: 36.8166, Val Loss: 45.9286
# Epoch 97/100, Train Loss: 37.7553, Val Loss: 43.2756
# Epoch 98/100, Train Loss: 37.3672, Val Loss: 44.0796
# Epoch 99/100, Train Loss: 37.1900, Val Loss: 44.8646
# Epoch 100/100, Train Loss: 36.6848, Val Loss: 44.4967
# Fold 2 - Val Loss: 43.2756, MAE: 4.5821, RMSE: 6.5762
#
# Fold 3
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_73578/3412344545.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch 1/100, Train Loss: 242.2700, Val Loss: 200.5922
# Epoch 2/100, Train Loss: 136.9376, Val Loss: 84.9218
# Epoch 3/100, Train Loss: 85.1881, Val Loss: 77.5543
# Epoch 4/100, Train Loss: 81.0161, Val Loss: 74.3012
# Epoch 5/100, Train Loss: 78.3925, Val Loss: 75.2803
# Epoch 6/100, Train Loss: 76.4969, Val Loss: 71.3549
# Epoch 7/100, Train Loss: 75.4421, Val Loss: 67.9247
# Epoch 8/100, Train Loss: 74.0869, Val Loss: 68.8100
# Epoch 9/100, Train Loss: 72.7561, Val Loss: 67.2865
# Epoch 10/100, Train Loss: 71.9577, Val Loss: 66.1494
# Epoch 11/100, Train Loss: 71.7784, Val Loss: 66.0147
# Epoch 12/100, Train Loss: 70.6677, Val Loss: 65.0590
# Epoch 13/100, Train Loss: 70.6242, Val Loss: 66.7215
# Epoch 14/100, Train Loss: 70.1775, Val Loss: 67.8436
# Epoch 15/100, Train Loss: 69.0113, Val Loss: 65.7122
# Epoch 16/100, Train Loss: 68.6837, Val Loss: 65.3643
# Epoch 17/100, Train Loss: 68.7277, Val Loss: 63.5798
# Epoch 18/100, Train Loss: 67.6006, Val Loss: 66.0958
# Epoch 19/100, Train Loss: 67.5526, Val Loss: 62.3520
# Epoch 20/100, Train Loss: 67.2687, Val Loss: 62.9840
# Epoch 21/100, Train Loss: 66.5236, Val Loss: 62.1863
# Epoch 22/100, Train Loss: 66.1973, Val Loss: 62.1116
# Epoch 23/100, Train Loss: 65.4911, Val Loss: 61.9558
# Epoch 24/100, Train Loss: 65.6494, Val Loss: 61.7143
# Epoch 25/100, Train Loss: 64.5861, Val Loss: 61.5979
# Epoch 26/100, Train Loss: 64.0958, Val Loss: 60.5804
# Epoch 27/100, Train Loss: 63.8364, Val Loss: 59.8528
# Epoch 28/100, Train Loss: 63.4552, Val Loss: 58.6025
# Epoch 29/100, Train Loss: 63.3682, Val Loss: 59.3467
# Epoch 30/100, Train Loss: 62.3402, Val Loss: 58.3956
# Epoch 31/100, Train Loss: 61.6220, Val Loss: 60.3321
# Epoch 32/100, Train Loss: 61.4000, Val Loss: 57.8480
# Epoch 33/100, Train Loss: 61.2040, Val Loss: 60.0101
# Epoch 34/100, Train Loss: 61.0685, Val Loss: 60.9194
# Epoch 35/100, Train Loss: 59.9132, Val Loss: 57.5583
# Epoch 36/100, Train Loss: 59.2097, Val Loss: 59.9849
# Epoch 37/100, Train Loss: 59.0739, Val Loss: 58.3304
# Epoch 38/100, Train Loss: 58.6373, Val Loss: 57.6285
# Epoch 39/100, Train Loss: 57.4355, Val Loss: 56.0766
# Epoch 40/100, Train Loss: 56.4729, Val Loss: 55.2743
# Epoch 41/100, Train Loss: 56.3391, Val Loss: 55.6538
# Epoch 42/100, Train Loss: 56.3730, Val Loss: 52.5457
# Epoch 43/100, Train Loss: 54.1854, Val Loss: 52.9818
# Epoch 44/100, Train Loss: 54.5219, Val Loss: 52.6674
# Epoch 45/100, Train Loss: 53.2067, Val Loss: 51.9239
# Epoch 46/100, Train Loss: 52.6687, Val Loss: 51.6934
# Epoch 47/100, Train Loss: 52.6691, Val Loss: 53.0945
# Epoch 48/100, Train Loss: 52.3859, Val Loss: 49.8640
# Epoch 49/100, Train Loss: 51.3378, Val Loss: 50.1799
# Epoch 50/100, Train Loss: 51.0315, Val Loss: 49.7725
# Epoch 51/100, Train Loss: 50.9976, Val Loss: 50.0772
# Epoch 52/100, Train Loss: 49.1390, Val Loss: 49.6383
# Epoch 53/100, Train Loss: 48.7902, Val Loss: 48.0694
# Epoch 54/100, Train Loss: 48.4704, Val Loss: 53.4219
# Epoch 55/100, Train Loss: 48.5668, Val Loss: 47.2741
# Epoch 56/100, Train Loss: 47.2044, Val Loss: 45.9696
# Epoch 57/100, Train Loss: 46.1698, Val Loss: 47.4593
# Epoch 58/100, Train Loss: 46.3522, Val Loss: 47.9999
# Epoch 59/100, Train Loss: 46.1590, Val Loss: 45.4453
# Epoch 60/100, Train Loss: 45.6445, Val Loss: 51.4582
# Epoch 61/100, Train Loss: 44.8201, Val Loss: 47.8597
# Epoch 62/100, Train Loss: 43.9626, Val Loss: 46.1047
# Epoch 63/100, Train Loss: 44.4487, Val Loss: 44.4499
# Epoch 64/100, Train Loss: 43.5228, Val Loss: 47.2742
# Epoch 65/100, Train Loss: 42.8179, Val Loss: 44.0369
# Epoch 66/100, Train Loss: 42.0921, Val Loss: 43.0202
# Epoch 67/100, Train Loss: 41.7298, Val Loss: 42.9120
# Epoch 68/100, Train Loss: 42.1797, Val Loss: 44.1572
# Epoch 69/100, Train Loss: 42.1171, Val Loss: 43.2082
# Epoch 70/100, Train Loss: 40.7242, Val Loss: 44.4749
# Epoch 71/100, Train Loss: 40.4215, Val Loss: 43.1656
# Epoch 72/100, Train Loss: 40.8945, Val Loss: 41.9661
# Epoch 73/100, Train Loss: 39.5878, Val Loss: 40.7938
# Epoch 74/100, Train Loss: 39.4783, Val Loss: 40.9208
# Epoch 75/100, Train Loss: 38.6192, Val Loss: 40.3644
# Epoch 76/100, Train Loss: 38.2676, Val Loss: 41.3657
# Epoch 77/100, Train Loss: 38.7100, Val Loss: 40.4018
# Epoch 78/100, Train Loss: 38.0017, Val Loss: 39.8086
# Epoch 79/100, Train Loss: 37.3577, Val Loss: 39.1485
# Epoch 80/100, Train Loss: 37.8915, Val Loss: 39.1840
# Epoch 81/100, Train Loss: 36.2605, Val Loss: 38.3261
# Epoch 82/100, Train Loss: 36.3218, Val Loss: 39.9723
# Epoch 83/100, Train Loss: 35.8792, Val Loss: 38.5824
# Epoch 84/100, Train Loss: 37.7035, Val Loss: 38.7216
# Epoch 85/100, Train Loss: 35.7342, Val Loss: 40.9433
# Epoch 86/100, Train Loss: 35.2395, Val Loss: 37.0092
# Epoch 87/100, Train Loss: 35.4020, Val Loss: 38.6422
# Epoch 88/100, Train Loss: 37.3140, Val Loss: 39.1272
# Epoch 89/100, Train Loss: 34.3486, Val Loss: 37.3836
# Epoch 90/100, Train Loss: 34.8813, Val Loss: 38.6222
# Epoch 91/100, Train Loss: 34.2720, Val Loss: 38.9589
# Epoch 92/100, Train Loss: 34.5898, Val Loss: 38.2205
# Epoch 93/100, Train Loss: 33.7358, Val Loss: 38.6413
# Epoch 94/100, Train Loss: 33.9091, Val Loss: 37.8717
# Epoch 95/100, Train Loss: 34.1741, Val Loss: 38.6296
# Epoch 96/100, Train Loss: 33.5347, Val Loss: 36.8950
# Epoch 97/100, Train Loss: 32.5330, Val Loss: 36.9241
# Epoch 98/100, Train Loss: 33.3901, Val Loss: 36.4845
# Epoch 99/100, Train Loss: 32.7214, Val Loss: 36.1983
# Epoch 100/100, Train Loss: 32.6286, Val Loss: 36.7958
# Fold 3 - Val Loss: 36.1983, MAE: 4.3011, RMSE: 6.0150
#
# Fold 4
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_73578/3412344545.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch 1/100, Train Loss: 240.5817, Val Loss: 201.1976
# Epoch 2/100, Train Loss: 130.4706, Val Loss: 93.9749
# Epoch 3/100, Train Loss: 86.8378, Val Loss: 84.3181
# Epoch 4/100, Train Loss: 80.8047, Val Loss: 84.0227
# Epoch 5/100, Train Loss: 77.9175, Val Loss: 82.4150
# Epoch 6/100, Train Loss: 76.7853, Val Loss: 75.9607
# Epoch 7/100, Train Loss: 75.1560, Val Loss: 77.4741
# Epoch 8/100, Train Loss: 74.5724, Val Loss: 77.3363
# Epoch 9/100, Train Loss: 73.6077, Val Loss: 76.7569
# Epoch 10/100, Train Loss: 73.1731, Val Loss: 73.7442
# Epoch 11/100, Train Loss: 72.4510, Val Loss: 74.9341
# Epoch 12/100, Train Loss: 72.2585, Val Loss: 74.3125
# Epoch 13/100, Train Loss: 71.4886, Val Loss: 73.2112
# Epoch 14/100, Train Loss: 70.6598, Val Loss: 72.3335
# Epoch 15/100, Train Loss: 70.4359, Val Loss: 72.1697
# Epoch 16/100, Train Loss: 69.5200, Val Loss: 72.9805
# Epoch 17/100, Train Loss: 69.5759, Val Loss: 70.7308
# Epoch 18/100, Train Loss: 69.1551, Val Loss: 72.0843
# Epoch 19/100, Train Loss: 68.8840, Val Loss: 71.7505
# Epoch 20/100, Train Loss: 68.5511, Val Loss: 69.7739
# Epoch 21/100, Train Loss: 68.0926, Val Loss: 70.4065
# Epoch 22/100, Train Loss: 68.0083, Val Loss: 69.7353
# Epoch 23/100, Train Loss: 67.2459, Val Loss: 74.2639
# Epoch 24/100, Train Loss: 67.2325, Val Loss: 69.5885
# Epoch 25/100, Train Loss: 66.8669, Val Loss: 69.7160
# Epoch 26/100, Train Loss: 66.8074, Val Loss: 68.3866
# Epoch 27/100, Train Loss: 66.2302, Val Loss: 72.3833
# Epoch 28/100, Train Loss: 66.5994, Val Loss: 69.4385
# Epoch 29/100, Train Loss: 66.0838, Val Loss: 71.2783
# Epoch 30/100, Train Loss: 66.0074, Val Loss: 69.6962
# Epoch 31/100, Train Loss: 65.6880, Val Loss: 67.6366
# Epoch 32/100, Train Loss: 65.7206, Val Loss: 67.6533
# Epoch 33/100, Train Loss: 64.8365, Val Loss: 68.5391
# Epoch 34/100, Train Loss: 65.5720, Val Loss: 67.4001
# Epoch 35/100, Train Loss: 64.9471, Val Loss: 68.2249
# Epoch 36/100, Train Loss: 64.7648, Val Loss: 67.5226
# Epoch 37/100, Train Loss: 64.7632, Val Loss: 67.2554
# Epoch 38/100, Train Loss: 64.0258, Val Loss: 66.2145
# Epoch 39/100, Train Loss: 64.4248, Val Loss: 66.6011
# Epoch 40/100, Train Loss: 63.5772, Val Loss: 66.0933
# Epoch 41/100, Train Loss: 63.3743, Val Loss: 70.0380
# Epoch 42/100, Train Loss: 63.4253, Val Loss: 65.3972
# Epoch 43/100, Train Loss: 62.5476, Val Loss: 64.8499
# Epoch 44/100, Train Loss: 62.0278, Val Loss: 67.4828
# Epoch 45/100, Train Loss: 62.2901, Val Loss: 64.7796
# Epoch 46/100, Train Loss: 61.5897, Val Loss: 65.4696
# Epoch 47/100, Train Loss: 61.4041, Val Loss: 68.4279
# Epoch 48/100, Train Loss: 61.3109, Val Loss: 64.6972
# Epoch 49/100, Train Loss: 60.8911, Val Loss: 64.9090
# Epoch 50/100, Train Loss: 61.0279, Val Loss: 64.5536
# Epoch 51/100, Train Loss: 59.6777, Val Loss: 63.5322
# Epoch 52/100, Train Loss: 59.6492, Val Loss: 64.0650
# Epoch 53/100, Train Loss: 58.9531, Val Loss: 63.6266
# Epoch 54/100, Train Loss: 59.2157, Val Loss: 63.6943
# Epoch 55/100, Train Loss: 59.1501, Val Loss: 62.8937
# Epoch 56/100, Train Loss: 59.2230, Val Loss: 61.8995
# Epoch 57/100, Train Loss: 58.1479, Val Loss: 62.8185
# Epoch 58/100, Train Loss: 57.7477, Val Loss: 63.1036
# Epoch 59/100, Train Loss: 57.2784, Val Loss: 60.7184
# Epoch 60/100, Train Loss: 57.5751, Val Loss: 61.6776
# Epoch 61/100, Train Loss: 57.2647, Val Loss: 61.1795
# Epoch 62/100, Train Loss: 55.8897, Val Loss: 62.1597
# Epoch 63/100, Train Loss: 55.6442, Val Loss: 60.7458
# Epoch 64/100, Train Loss: 54.8464, Val Loss: 60.1892
# Epoch 65/100, Train Loss: 55.1125, Val Loss: 64.4149
# Epoch 66/100, Train Loss: 54.3895, Val Loss: 59.7168
# Epoch 67/100, Train Loss: 53.6360, Val Loss: 59.3950
# Epoch 68/100, Train Loss: 54.1173, Val Loss: 59.7337
# Epoch 69/100, Train Loss: 52.8316, Val Loss: 61.9150
# Epoch 70/100, Train Loss: 52.8728, Val Loss: 59.8683
# Epoch 71/100, Train Loss: 51.5055, Val Loss: 58.4067
# Epoch 72/100, Train Loss: 52.2650, Val Loss: 56.4728
# Epoch 73/100, Train Loss: 51.0621, Val Loss: 55.9763
# Epoch 74/100, Train Loss: 50.1052, Val Loss: 57.8150
# Epoch 75/100, Train Loss: 50.6551, Val Loss: 56.1864
# Epoch 76/100, Train Loss: 51.0473, Val Loss: 58.1989
# Epoch 77/100, Train Loss: 48.1286, Val Loss: 53.6748
# Epoch 78/100, Train Loss: 48.2088, Val Loss: 55.5422
# Epoch 79/100, Train Loss: 46.6335, Val Loss: 55.4368
# Epoch 80/100, Train Loss: 47.9040, Val Loss: 52.2723
# Epoch 81/100, Train Loss: 47.3819, Val Loss: 54.3593
# Epoch 82/100, Train Loss: 46.7420, Val Loss: 53.6421
# Epoch 83/100, Train Loss: 46.2934, Val Loss: 53.5887
# Epoch 84/100, Train Loss: 45.5052, Val Loss: 53.2527
# Epoch 85/100, Train Loss: 44.6784, Val Loss: 51.6720
# Epoch 86/100, Train Loss: 44.8538, Val Loss: 51.2443
# Epoch 87/100, Train Loss: 44.3393, Val Loss: 52.9108
# Epoch 88/100, Train Loss: 43.7101, Val Loss: 51.3348
# Epoch 89/100, Train Loss: 43.0975, Val Loss: 49.7816
# Epoch 90/100, Train Loss: 43.0500, Val Loss: 49.9219
# Epoch 91/100, Train Loss: 42.2674, Val Loss: 50.1344
# Epoch 92/100, Train Loss: 42.1577, Val Loss: 50.2852
# Epoch 93/100, Train Loss: 40.9989, Val Loss: 50.1738
# Epoch 94/100, Train Loss: 41.7415, Val Loss: 51.1119
# Epoch 95/100, Train Loss: 42.5622, Val Loss: 50.4637
# Epoch 96/100, Train Loss: 40.8956, Val Loss: 47.6990
# Epoch 97/100, Train Loss: 40.4394, Val Loss: 49.6709
# Epoch 98/100, Train Loss: 39.7963, Val Loss: 48.7465
# Epoch 99/100, Train Loss: 39.0962, Val Loss: 47.7046
# Epoch 100/100, Train Loss: 39.3734, Val Loss: 47.8118
# Fold 4 - Val Loss: 47.6990, MAE: 4.7803, RMSE: 6.9085
#
# Fold 5
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_73578/3412344545.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch 1/100, Train Loss: 243.1522, Val Loss: 199.8112
# Epoch 2/100, Train Loss: 145.2670, Val Loss: 87.3651
# Epoch 3/100, Train Loss: 87.8873, Val Loss: 79.5735
# Epoch 4/100, Train Loss: 83.6562, Val Loss: 75.4123
# Epoch 5/100, Train Loss: 80.9946, Val Loss: 73.6728
# Epoch 6/100, Train Loss: 78.2872, Val Loss: 75.5868
# Epoch 7/100, Train Loss: 77.3523, Val Loss: 70.1239
# Epoch 8/100, Train Loss: 75.7364, Val Loss: 69.5849
# Epoch 9/100, Train Loss: 75.5707, Val Loss: 69.2263
# Epoch 10/100, Train Loss: 74.0288, Val Loss: 67.5589
# Epoch 11/100, Train Loss: 72.6737, Val Loss: 68.4378
# Epoch 12/100, Train Loss: 72.3557, Val Loss: 68.4907
# Epoch 13/100, Train Loss: 71.6940, Val Loss: 65.1470
# Epoch 14/100, Train Loss: 71.3085, Val Loss: 69.2056
# Epoch 15/100, Train Loss: 70.7565, Val Loss: 65.7655
# Epoch 16/100, Train Loss: 70.6000, Val Loss: 67.5651
# Epoch 17/100, Train Loss: 70.3679, Val Loss: 65.4910
# Epoch 18/100, Train Loss: 70.6347, Val Loss: 63.7418
# Epoch 19/100, Train Loss: 69.5310, Val Loss: 67.4108
# Epoch 20/100, Train Loss: 68.9880, Val Loss: 64.0908
# Epoch 21/100, Train Loss: 68.4957, Val Loss: 63.2818
# Epoch 22/100, Train Loss: 68.2990, Val Loss: 62.8165
# Epoch 23/100, Train Loss: 68.0528, Val Loss: 62.1838
# Epoch 24/100, Train Loss: 67.9264, Val Loss: 62.2519
# Epoch 25/100, Train Loss: 66.8913, Val Loss: 64.9831
# Epoch 26/100, Train Loss: 66.8472, Val Loss: 62.1634
# Epoch 27/100, Train Loss: 66.6197, Val Loss: 62.8263
# Epoch 28/100, Train Loss: 66.2451, Val Loss: 62.2486
# Epoch 29/100, Train Loss: 65.6547, Val Loss: 61.4078
# Epoch 30/100, Train Loss: 65.8554, Val Loss: 65.7672
# Epoch 31/100, Train Loss: 66.0617, Val Loss: 61.8408
# Epoch 32/100, Train Loss: 65.0087, Val Loss: 61.7824
# Epoch 33/100, Train Loss: 64.8869, Val Loss: 60.3468
# Epoch 34/100, Train Loss: 65.5725, Val Loss: 62.5424
# Epoch 35/100, Train Loss: 64.8817, Val Loss: 60.8979
# Epoch 36/100, Train Loss: 63.6299, Val Loss: 59.5358
# Epoch 37/100, Train Loss: 63.8440, Val Loss: 60.3992
# Epoch 38/100, Train Loss: 63.3689, Val Loss: 62.2285
# Epoch 39/100, Train Loss: 63.0397, Val Loss: 61.1422
# Epoch 40/100, Train Loss: 62.4440, Val Loss: 60.4352
# Epoch 41/100, Train Loss: 61.5387, Val Loss: 58.7271
# Epoch 42/100, Train Loss: 62.0501, Val Loss: 59.8681
# Epoch 43/100, Train Loss: 61.7375, Val Loss: 60.1040
# Epoch 44/100, Train Loss: 61.2796, Val Loss: 59.5279
# Epoch 45/100, Train Loss: 60.7464, Val Loss: 60.4776
# Epoch 46/100, Train Loss: 60.3088, Val Loss: 60.7623
# Epoch 47/100, Train Loss: 59.2538, Val Loss: 60.9173
# Epoch 48/100, Train Loss: 59.0361, Val Loss: 59.1770
# Epoch 49/100, Train Loss: 59.4967, Val Loss: 57.4840
# Epoch 50/100, Train Loss: 58.7240, Val Loss: 57.5092
# Epoch 51/100, Train Loss: 58.3074, Val Loss: 59.4683
# Epoch 52/100, Train Loss: 57.6024, Val Loss: 56.0211
# Epoch 53/100, Train Loss: 57.0624, Val Loss: 57.0223
# Epoch 54/100, Train Loss: 56.3106, Val Loss: 56.2829
# Epoch 55/100, Train Loss: 56.7338, Val Loss: 55.6231
# Epoch 56/100, Train Loss: 55.0313, Val Loss: 57.7551
# Epoch 57/100, Train Loss: 55.0336, Val Loss: 54.4926
# Epoch 58/100, Train Loss: 54.6062, Val Loss: 56.3273
# Epoch 59/100, Train Loss: 54.4421, Val Loss: 55.2374
# Epoch 60/100, Train Loss: 54.1099, Val Loss: 53.7825
# Epoch 61/100, Train Loss: 53.0973, Val Loss: 52.4536
# Epoch 62/100, Train Loss: 52.7003, Val Loss: 52.7695
# Epoch 63/100, Train Loss: 51.7015, Val Loss: 53.2488
# Epoch 64/100, Train Loss: 51.5058, Val Loss: 56.0002
# Epoch 65/100, Train Loss: 50.9152, Val Loss: 51.1511
# Epoch 66/100, Train Loss: 50.2289, Val Loss: 51.4164
# Epoch 67/100, Train Loss: 49.7475, Val Loss: 50.9803
# Epoch 68/100, Train Loss: 48.9136, Val Loss: 51.0426
# Epoch 69/100, Train Loss: 49.5417, Val Loss: 51.8227
# Epoch 70/100, Train Loss: 48.2027, Val Loss: 48.7594
# Epoch 71/100, Train Loss: 47.6576, Val Loss: 49.4852
# Epoch 72/100, Train Loss: 48.3739, Val Loss: 49.7543
# Epoch 73/100, Train Loss: 46.5241, Val Loss: 54.8183
# Epoch 74/100, Train Loss: 46.8323, Val Loss: 48.6051
# Epoch 75/100, Train Loss: 45.9977, Val Loss: 50.6924
# Epoch 76/100, Train Loss: 45.1055, Val Loss: 47.9817
# Epoch 77/100, Train Loss: 45.4274, Val Loss: 47.2263
# Epoch 78/100, Train Loss: 45.7326, Val Loss: 46.9464
# Epoch 79/100, Train Loss: 44.5790, Val Loss: 46.4295
# Epoch 80/100, Train Loss: 43.3412, Val Loss: 47.8890
# Epoch 81/100, Train Loss: 43.8227, Val Loss: 48.7583
# Epoch 82/100, Train Loss: 42.3976, Val Loss: 46.7942
# Epoch 83/100, Train Loss: 42.6429, Val Loss: 45.9548
# Epoch 84/100, Train Loss: 43.0789, Val Loss: 46.8598
# Epoch 85/100, Train Loss: 41.8645, Val Loss: 46.0681
# Epoch 86/100, Train Loss: 41.8907, Val Loss: 45.9626
# Epoch 87/100, Train Loss: 41.2542, Val Loss: 45.5628
# Epoch 88/100, Train Loss: 41.0278, Val Loss: 45.0232
# Epoch 89/100, Train Loss: 40.7719, Val Loss: 44.7810
# Epoch 90/100, Train Loss: 40.3004, Val Loss: 43.5821
# Epoch 91/100, Train Loss: 39.0626, Val Loss: 44.6360
# Epoch 92/100, Train Loss: 39.1624, Val Loss: 47.5509
# Epoch 93/100, Train Loss: 39.4881, Val Loss: 44.0745
# Epoch 94/100, Train Loss: 39.3938, Val Loss: 44.0929
# Epoch 95/100, Train Loss: 39.0210, Val Loss: 45.2861
# Epoch 96/100, Train Loss: 38.3468, Val Loss: 44.4098
# Epoch 97/100, Train Loss: 38.2771, Val Loss: 49.6992
# Epoch 98/100, Train Loss: 37.6465, Val Loss: 44.5586
# Epoch 99/100, Train Loss: 37.5861, Val Loss: 42.5813
# Epoch 100/100, Train Loss: 37.3539, Val Loss: 43.6040
# Fold 5 - Val Loss: 42.5813, MAE: 4.5656, RMSE: 6.5249
#
# Average Val Loss: 41.5014
# Average MAE: 4.5178
# Average RMSE: 6.4338
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_73578/3412344545.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
