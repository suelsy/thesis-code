# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_absolute_error, mean_squared_error
import random

# 设置随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# 在代码的开头设置随机种子
set_seed(42)

# 读取数据
data = pd.read_csv('final_50_all.csv')

# 特征工程
data['hour'] = pd.to_datetime(data['hour'])
data['year'] = data['hour'].dt.year
data['month'] = data['hour'].dt.month
data['day'] = data['hour'].dt.day
data['hour_of_day'] = data['hour'].dt.hour
data['weekday'] = data['hour'].dt.weekday

data['hour_sin'] = np.sin(2 * np.pi * data['hour_of_day'] / 24)
data['hour_cos'] = np.cos(2 * np.pi * data['hour_of_day'] / 24)
data['weekday_sin'] = np.sin(2 * np.pi * data['weekday'] / 7)
data['weekday_cos'] = np.cos(2 * np.pi * data['weekday'] / 7)
data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

# 数值特征缩放
num_features = ['temperature_2m (°C)', 'apparent_temperature (°C)', 'rain (mm)', 'wind_speed_100m (km/h)']
scaler = MinMaxScaler()
data[num_features] = scaler.fit_transform(data[num_features])

data.drop(['month','day','hour', 'hour_of_day', 'weekday'], axis=1, inplace=True)

# 提取最终特征和目标
features = num_features + ['hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos','month_sin','month_cos'] 
target = 'ride_count'

X = data[features].values
y = data[target].values

# 数据标准化
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

def create_sequences(data, target, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(target[i + sequence_length])
    return np.array(X), np.array(y)

# 设置序列长度
sequence_length = 48  # 例如使用过去24小时的数据预测
X, y = create_sequences(X, y, sequence_length)

# 使用 KFold 进行交叉验证
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# 初始化存储结果的列表
test_losses = []
maes = []
rmses = []

# 交叉验证过程
for fold, (train_index, val_index) in enumerate(kf.split(X)):
    print(f"\nFold {fold + 1}")

    # 分割数据
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # 转换为张量
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

    # 数据加载器
    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=32)

    # GRU 模型定义
    class GRUModel(nn.Module):
        def __init__(self, input_size, hidden_size, output_size, dropout=0.2):
            super(GRUModel, self).__init__()
            self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
            self.fc = nn.Linear(hidden_size, output_size)
            self.dropout = nn.Dropout(dropout)
        
        def forward(self, x):
            out, _ = self.gru(x)
            out = self.dropout(out[:, -1, :])
            out = self.fc(out)
            return out

    # 模型实例化
    input_size = len(features)
    hidden_size = 64
    output_size = 1
    model = GRUModel(input_size, hidden_size, output_size)

    # 损失函数和优化器
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # 训练与验证
    patience = 10
    best_val_loss = float('inf')
    early_stop_counter = 0
    epochs = 100

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = model(X_batch).squeeze()
            loss = criterion(y_pred, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)

        # 验证阶段
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                y_pred = model(X_batch).squeeze()
                loss = criterion(y_pred, y_batch)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # 早停机制
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            torch.save(model.state_dict(), f'best_model_fold{fold+1}.pth')  # 保存最佳模型
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print("Early stopping triggered")
            break

    # 测试集评估
    model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
    model.eval()
    val_loss = 0
    y_preds = []
    y_trues = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            y_pred = model(X_batch).squeeze()
            y_preds.extend(y_pred.squeeze().tolist())
            y_trues.extend(y_batch.tolist())
            loss = criterion(y_pred.squeeze(), y_batch)
            val_loss += loss.item()

    val_loss /= len(val_loader)
    mae = mean_absolute_error(y_trues, y_preds)
    rmse = mean_squared_error(y_trues, y_preds, squared=False)

    test_losses.append(val_loss)
    maes.append(mae)
    rmses.append(rmse)

    print(f"Fold {fold+1} - Val Loss: {val_loss:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# 输出所有折的平均性能
print(f"\nAverage Val Loss: {np.mean(test_losses):.4f}")
print(f"Average MAE: {np.mean(maes):.4f}")
print(f"Average RMSE: {np.mean(rmses):.4f}")
# Out:
# Fold 1
# Epoch 1/100, Train Loss: 246.1560, Val Loss: 197.8238
# Epoch 2/100, Train Loss: 175.6584, Val Loss: 94.2963
# Epoch 3/100, Train Loss: 94.1037, Val Loss: 73.2805
# Epoch 4/100, Train Loss: 84.5418, Val Loss: 71.5398
# Epoch 5/100, Train Loss: 81.6871, Val Loss: 66.2769
# Epoch 6/100, Train Loss: 78.5094, Val Loss: 66.4085
# Epoch 7/100, Train Loss: 76.0935, Val Loss: 60.9171
# Epoch 8/100, Train Loss: 74.1399, Val Loss: 58.2668
# Epoch 9/100, Train Loss: 72.0687, Val Loss: 59.8770
# Epoch 10/100, Train Loss: 71.4499, Val Loss: 56.2443
# Epoch 11/100, Train Loss: 70.0213, Val Loss: 59.7523
# Epoch 12/100, Train Loss: 68.9396, Val Loss: 56.6070
# Epoch 13/100, Train Loss: 69.1519, Val Loss: 55.9724
# Epoch 14/100, Train Loss: 68.9551, Val Loss: 54.9604
# Epoch 15/100, Train Loss: 68.1389, Val Loss: 55.6181
# Epoch 16/100, Train Loss: 66.6021, Val Loss: 53.9006
# Epoch 17/100, Train Loss: 66.2443, Val Loss: 53.9918
# Epoch 18/100, Train Loss: 66.5832, Val Loss: 53.3561
# Epoch 19/100, Train Loss: 65.3172, Val Loss: 54.2620
# Epoch 20/100, Train Loss: 65.4716, Val Loss: 52.6848
# Epoch 21/100, Train Loss: 64.7811, Val Loss: 52.7536
# Epoch 22/100, Train Loss: 64.0821, Val Loss: 54.8267
# Epoch 23/100, Train Loss: 64.0318, Val Loss: 53.2286
# Epoch 24/100, Train Loss: 63.2272, Val Loss: 51.3349
# Epoch 25/100, Train Loss: 62.3968, Val Loss: 50.9566
# Epoch 26/100, Train Loss: 61.4900, Val Loss: 51.5101
# Epoch 27/100, Train Loss: 61.8049, Val Loss: 53.3551
# Epoch 28/100, Train Loss: 60.8974, Val Loss: 49.6991
# Epoch 29/100, Train Loss: 60.4916, Val Loss: 50.0065
# Epoch 30/100, Train Loss: 59.5461, Val Loss: 49.3482
# Epoch 31/100, Train Loss: 59.2586, Val Loss: 48.7290
# Epoch 32/100, Train Loss: 59.0345, Val Loss: 47.5910
# Epoch 33/100, Train Loss: 58.4238, Val Loss: 48.0938
# Epoch 34/100, Train Loss: 58.0280, Val Loss: 49.0284
# Epoch 35/100, Train Loss: 56.9632, Val Loss: 47.5700
# Epoch 36/100, Train Loss: 57.0755, Val Loss: 51.3111
# Epoch 37/100, Train Loss: 56.7475, Val Loss: 47.0011
# Epoch 38/100, Train Loss: 56.0221, Val Loss: 46.8753
# Epoch 39/100, Train Loss: 54.7512, Val Loss: 47.8978
# Epoch 40/100, Train Loss: 54.2999, Val Loss: 46.8486
# Epoch 41/100, Train Loss: 54.1920, Val Loss: 47.9571
# Epoch 42/100, Train Loss: 53.0969, Val Loss: 46.6835
# Epoch 43/100, Train Loss: 52.5173, Val Loss: 43.9093
# Epoch 44/100, Train Loss: 51.3904, Val Loss: 44.0773
# Epoch 45/100, Train Loss: 50.0218, Val Loss: 44.2457
# Epoch 46/100, Train Loss: 50.0527, Val Loss: 43.6812
# Epoch 47/100, Train Loss: 49.9257, Val Loss: 42.7442
# Epoch 48/100, Train Loss: 49.6662, Val Loss: 42.6710
# Epoch 49/100, Train Loss: 48.5841, Val Loss: 43.4300
# Epoch 50/100, Train Loss: 47.5933, Val Loss: 43.4523
# Epoch 51/100, Train Loss: 47.4047, Val Loss: 41.4173
# Epoch 52/100, Train Loss: 46.7358, Val Loss: 41.6753
# Epoch 53/100, Train Loss: 45.9250, Val Loss: 39.5909
# Epoch 54/100, Train Loss: 45.7286, Val Loss: 39.6370
# Epoch 55/100, Train Loss: 45.4192, Val Loss: 39.9686
# Epoch 56/100, Train Loss: 45.3744, Val Loss: 41.6986
# Epoch 57/100, Train Loss: 43.9384, Val Loss: 39.1369
# Epoch 58/100, Train Loss: 43.4126, Val Loss: 39.1248
# Epoch 59/100, Train Loss: 42.6719, Val Loss: 37.0107
# Epoch 60/100, Train Loss: 42.0225, Val Loss: 39.2184
# Epoch 61/100, Train Loss: 42.0759, Val Loss: 37.7362
# Epoch 62/100, Train Loss: 42.2096, Val Loss: 38.5856
# Epoch 63/100, Train Loss: 41.5313, Val Loss: 38.9895
# Epoch 64/100, Train Loss: 41.0901, Val Loss: 36.0414
# Epoch 65/100, Train Loss: 40.7107, Val Loss: 39.5296
# Epoch 66/100, Train Loss: 40.0160, Val Loss: 36.5033
# Epoch 67/100, Train Loss: 39.7620, Val Loss: 36.8832
# Epoch 68/100, Train Loss: 39.3796, Val Loss: 37.9352
# Epoch 69/100, Train Loss: 39.4876, Val Loss: 37.2385
# Epoch 70/100, Train Loss: 38.5706, Val Loss: 35.7923
# Epoch 71/100, Train Loss: 38.1687, Val Loss: 34.5761
# Epoch 72/100, Train Loss: 37.6480, Val Loss: 34.8451
# Epoch 73/100, Train Loss: 37.9911, Val Loss: 35.0807
# Epoch 74/100, Train Loss: 37.5474, Val Loss: 35.9675
# Epoch 75/100, Train Loss: 37.4405, Val Loss: 34.7953
# Epoch 76/100, Train Loss: 36.4899, Val Loss: 33.4689
# Epoch 77/100, Train Loss: 36.5890, Val Loss: 35.8865
# Epoch 78/100, Train Loss: 36.5687, Val Loss: 34.8820
# Epoch 79/100, Train Loss: 35.9296, Val Loss: 33.2642
# Epoch 80/100, Train Loss: 35.5910, Val Loss: 34.8053
# Epoch 81/100, Train Loss: 36.0039, Val Loss: 35.7886
# Epoch 82/100, Train Loss: 35.3092, Val Loss: 33.1959
# Epoch 83/100, Train Loss: 35.3571, Val Loss: 33.8319
# Epoch 84/100, Train Loss: 34.8505, Val Loss: 33.3540
# Epoch 85/100, Train Loss: 34.9651, Val Loss: 34.3123
# Epoch 86/100, Train Loss: 34.0094, Val Loss: 32.3853
# Epoch 87/100, Train Loss: 34.2947, Val Loss: 34.6452
# Epoch 88/100, Train Loss: 33.6868, Val Loss: 33.7010
# Epoch 89/100, Train Loss: 33.9256, Val Loss: 32.5184
# Epoch 90/100, Train Loss: 33.4029, Val Loss: 32.7295
# Epoch 91/100, Train Loss: 33.3812, Val Loss: 32.6834
# Epoch 92/100, Train Loss: 32.7763, Val Loss: 32.8957
# Epoch 93/100, Train Loss: 33.6957, Val Loss: 31.7870
# Epoch 94/100, Train Loss: 32.7199, Val Loss: 31.3226
# Epoch 95/100, Train Loss: 32.3040, Val Loss: 33.5606
# Epoch 96/100, Train Loss: 33.0009, Val Loss: 31.9636
# Epoch 97/100, Train Loss: 32.1650, Val Loss: 31.2253
# Epoch 98/100, Train Loss: 32.3903, Val Loss: 31.7504
# Epoch 99/100, Train Loss: 31.7045, Val Loss: 32.6362
# Epoch 100/100, Train Loss: 31.9573, Val Loss: 33.5731
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_80933/1901634337.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 1 - Val Loss: 31.2253, MAE: 4.0611, RMSE: 5.5804
#
# Fold 2
# Epoch 1/100, Train Loss: 242.0155, Val Loss: 201.6127
# Epoch 2/100, Train Loss: 154.3249, Val Loss: 85.6566
# Epoch 3/100, Train Loss: 86.5878, Val Loss: 80.0892
# Epoch 4/100, Train Loss: 84.9729, Val Loss: 82.4470
# Epoch 5/100, Train Loss: 83.6757, Val Loss: 80.0780
# Epoch 6/100, Train Loss: 81.5831, Val Loss: 76.3372
# Epoch 7/100, Train Loss: 78.3228, Val Loss: 70.9617
# Epoch 8/100, Train Loss: 75.6154, Val Loss: 69.3608
# Epoch 9/100, Train Loss: 73.9364, Val Loss: 69.5810
# Epoch 10/100, Train Loss: 72.2543, Val Loss: 68.2846
# Epoch 11/100, Train Loss: 71.2992, Val Loss: 66.3261
# Epoch 12/100, Train Loss: 70.2745, Val Loss: 69.2637
# Epoch 13/100, Train Loss: 69.0673, Val Loss: 66.3946
# Epoch 14/100, Train Loss: 69.2494, Val Loss: 64.6332
# Epoch 15/100, Train Loss: 68.1706, Val Loss: 63.8091
# Epoch 16/100, Train Loss: 67.3103, Val Loss: 62.9145
# Epoch 17/100, Train Loss: 66.2335, Val Loss: 62.6126
# Epoch 18/100, Train Loss: 65.7499, Val Loss: 62.7655
# Epoch 19/100, Train Loss: 65.0301, Val Loss: 60.9922
# Epoch 20/100, Train Loss: 64.9904, Val Loss: 60.5249
# Epoch 21/100, Train Loss: 63.6121, Val Loss: 60.3936
# Epoch 22/100, Train Loss: 64.1553, Val Loss: 60.6896
# Epoch 23/100, Train Loss: 63.1635, Val Loss: 64.9402
# Epoch 24/100, Train Loss: 62.4499, Val Loss: 58.1690
# Epoch 25/100, Train Loss: 61.8694, Val Loss: 58.5225
# Epoch 26/100, Train Loss: 61.8990, Val Loss: 59.8946
# Epoch 27/100, Train Loss: 60.7518, Val Loss: 57.6507
# Epoch 28/100, Train Loss: 61.4033, Val Loss: 57.6743
# Epoch 29/100, Train Loss: 59.5202, Val Loss: 58.9850
# Epoch 30/100, Train Loss: 58.8978, Val Loss: 56.7456
# Epoch 31/100, Train Loss: 58.9917, Val Loss: 57.2283
# Epoch 32/100, Train Loss: 58.0121, Val Loss: 55.8703
# Epoch 33/100, Train Loss: 57.8060, Val Loss: 57.7696
# Epoch 34/100, Train Loss: 57.4588, Val Loss: 58.0401
# Epoch 35/100, Train Loss: 58.0573, Val Loss: 58.9373
# Epoch 36/100, Train Loss: 56.8777, Val Loss: 56.1926
# Epoch 37/100, Train Loss: 56.7265, Val Loss: 55.7559
# Epoch 38/100, Train Loss: 55.8673, Val Loss: 54.5479
# Epoch 39/100, Train Loss: 55.1891, Val Loss: 58.8208
# Epoch 40/100, Train Loss: 54.8635, Val Loss: 54.4094
# Epoch 41/100, Train Loss: 54.7056, Val Loss: 53.8574
# Epoch 42/100, Train Loss: 53.7341, Val Loss: 52.5287
# Epoch 43/100, Train Loss: 53.7942, Val Loss: 55.6552
# Epoch 44/100, Train Loss: 53.2870, Val Loss: 51.8205
# Epoch 45/100, Train Loss: 52.1647, Val Loss: 52.9512
# Epoch 46/100, Train Loss: 51.8468, Val Loss: 52.0867
# Epoch 47/100, Train Loss: 51.7378, Val Loss: 65.6182
# Epoch 48/100, Train Loss: 50.7340, Val Loss: 51.9699
# Epoch 49/100, Train Loss: 50.4290, Val Loss: 51.0023
# Epoch 50/100, Train Loss: 49.7479, Val Loss: 50.0879
# Epoch 51/100, Train Loss: 49.5363, Val Loss: 49.6272
# Epoch 52/100, Train Loss: 49.7196, Val Loss: 56.2140
# Epoch 53/100, Train Loss: 48.7638, Val Loss: 48.6732
# Epoch 54/100, Train Loss: 48.9257, Val Loss: 52.7813
# Epoch 55/100, Train Loss: 47.3601, Val Loss: 47.2535
# Epoch 56/100, Train Loss: 47.2277, Val Loss: 48.9714
# Epoch 57/100, Train Loss: 46.4018, Val Loss: 48.1030
# Epoch 58/100, Train Loss: 46.9079, Val Loss: 46.8587
# Epoch 59/100, Train Loss: 45.0511, Val Loss: 48.7202
# Epoch 60/100, Train Loss: 44.5730, Val Loss: 48.6910
# Epoch 61/100, Train Loss: 44.5409, Val Loss: 45.3684
# Epoch 62/100, Train Loss: 45.0092, Val Loss: 44.6362
# Epoch 63/100, Train Loss: 43.7710, Val Loss: 43.9176
# Epoch 64/100, Train Loss: 42.9534, Val Loss: 44.3692
# Epoch 65/100, Train Loss: 42.8676, Val Loss: 44.8484
# Epoch 66/100, Train Loss: 42.8281, Val Loss: 44.0133
# Epoch 67/100, Train Loss: 42.8547, Val Loss: 44.4610
# Epoch 68/100, Train Loss: 41.6919, Val Loss: 46.9757
# Epoch 69/100, Train Loss: 41.6345, Val Loss: 43.1967
# Epoch 70/100, Train Loss: 41.1541, Val Loss: 43.4424
# Epoch 71/100, Train Loss: 40.1463, Val Loss: 48.1613
# Epoch 72/100, Train Loss: 41.4233, Val Loss: 42.8172
# Epoch 73/100, Train Loss: 40.6437, Val Loss: 51.8024
# Epoch 74/100, Train Loss: 40.3964, Val Loss: 43.4466
# Epoch 75/100, Train Loss: 39.4223, Val Loss: 43.3371
# Epoch 76/100, Train Loss: 39.0970, Val Loss: 41.3447
# Epoch 77/100, Train Loss: 38.2624, Val Loss: 47.2223
# Epoch 78/100, Train Loss: 37.9950, Val Loss: 41.6188
# Epoch 79/100, Train Loss: 37.6626, Val Loss: 40.7036
# Epoch 80/100, Train Loss: 38.3919, Val Loss: 41.5231
# Epoch 81/100, Train Loss: 37.5637, Val Loss: 40.4374
# Epoch 82/100, Train Loss: 36.6250, Val Loss: 39.8125
# Epoch 83/100, Train Loss: 37.0519, Val Loss: 41.6737
# Epoch 84/100, Train Loss: 38.0820, Val Loss: 41.0999
# Epoch 85/100, Train Loss: 37.4990, Val Loss: 40.9188
# Epoch 86/100, Train Loss: 35.5559, Val Loss: 40.5420
# Epoch 87/100, Train Loss: 36.0456, Val Loss: 38.7359
# Epoch 88/100, Train Loss: 35.6921, Val Loss: 39.1851
# Epoch 89/100, Train Loss: 35.8623, Val Loss: 44.6306
# Epoch 90/100, Train Loss: 34.7498, Val Loss: 39.4136
# Epoch 91/100, Train Loss: 34.5262, Val Loss: 42.8332
# Epoch 92/100, Train Loss: 34.7004, Val Loss: 42.6226
# Epoch 93/100, Train Loss: 35.1834, Val Loss: 39.2043
# Epoch 94/100, Train Loss: 35.0335, Val Loss: 40.0139
# Epoch 95/100, Train Loss: 34.5977, Val Loss: 39.2811
# Epoch 96/100, Train Loss: 33.9957, Val Loss: 38.8693
# Epoch 97/100, Train Loss: 34.8991, Val Loss: 37.3877
# Epoch 98/100, Train Loss: 33.9689, Val Loss: 38.6893
# Epoch 99/100, Train Loss: 34.0557, Val Loss: 38.7796
# Epoch 100/100, Train Loss: 33.6072, Val Loss: 37.9885
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_80933/1901634337.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 2 - Val Loss: 37.3877, MAE: 4.2895, RMSE: 6.1140
#
# Fold 3
# Epoch 1/100, Train Loss: 242.1657, Val Loss: 204.7490
# Epoch 2/100, Train Loss: 150.9366, Val Loss: 87.1513
# Epoch 3/100, Train Loss: 85.8048, Val Loss: 75.7719
# Epoch 4/100, Train Loss: 80.1506, Val Loss: 72.5501
# Epoch 5/100, Train Loss: 76.9892, Val Loss: 69.6114
# Epoch 6/100, Train Loss: 74.9953, Val Loss: 67.8916
# Epoch 7/100, Train Loss: 73.1502, Val Loss: 65.0174
# Epoch 8/100, Train Loss: 72.3951, Val Loss: 64.4353
# Epoch 9/100, Train Loss: 71.1912, Val Loss: 62.5632
# Epoch 10/100, Train Loss: 69.0815, Val Loss: 65.5396
# Epoch 11/100, Train Loss: 68.9703, Val Loss: 60.7355
# Epoch 12/100, Train Loss: 68.2742, Val Loss: 62.6635
# Epoch 13/100, Train Loss: 67.8118, Val Loss: 59.0013
# Epoch 14/100, Train Loss: 66.9994, Val Loss: 62.1042
# Epoch 15/100, Train Loss: 65.7139, Val Loss: 59.5951
# Epoch 16/100, Train Loss: 65.9739, Val Loss: 58.6396
# Epoch 17/100, Train Loss: 64.7203, Val Loss: 58.9255
# Epoch 18/100, Train Loss: 64.3513, Val Loss: 57.0052
# Epoch 19/100, Train Loss: 63.7343, Val Loss: 57.6680
# Epoch 20/100, Train Loss: 63.4332, Val Loss: 56.5444
# Epoch 21/100, Train Loss: 62.5223, Val Loss: 58.8045
# Epoch 22/100, Train Loss: 61.5066, Val Loss: 56.4782
# Epoch 23/100, Train Loss: 61.0803, Val Loss: 56.7740
# Epoch 24/100, Train Loss: 61.6093, Val Loss: 55.0394
# Epoch 25/100, Train Loss: 59.8813, Val Loss: 59.3350
# Epoch 26/100, Train Loss: 59.9491, Val Loss: 55.0794
# Epoch 27/100, Train Loss: 58.8904, Val Loss: 55.3760
# Epoch 28/100, Train Loss: 58.7329, Val Loss: 53.1993
# Epoch 29/100, Train Loss: 58.2164, Val Loss: 56.5332
# Epoch 30/100, Train Loss: 56.8246, Val Loss: 62.6507
# Epoch 31/100, Train Loss: 56.2424, Val Loss: 51.9005
# Epoch 32/100, Train Loss: 56.2726, Val Loss: 51.3930
# Epoch 33/100, Train Loss: 55.4205, Val Loss: 50.5459
# Epoch 34/100, Train Loss: 54.3752, Val Loss: 50.9044
# Epoch 35/100, Train Loss: 53.6625, Val Loss: 51.4312
# Epoch 36/100, Train Loss: 52.7519, Val Loss: 53.5928
# Epoch 37/100, Train Loss: 52.4434, Val Loss: 52.8554
# Epoch 38/100, Train Loss: 51.4455, Val Loss: 47.6734
# Epoch 39/100, Train Loss: 51.2099, Val Loss: 48.3301
# Epoch 40/100, Train Loss: 50.2301, Val Loss: 48.3189
# Epoch 41/100, Train Loss: 50.3247, Val Loss: 47.3265
# Epoch 42/100, Train Loss: 49.3344, Val Loss: 46.7022
# Epoch 43/100, Train Loss: 49.6730, Val Loss: 45.8747
# Epoch 44/100, Train Loss: 48.1620, Val Loss: 45.7590
# Epoch 45/100, Train Loss: 48.6266, Val Loss: 45.1929
# Epoch 46/100, Train Loss: 47.5084, Val Loss: 46.3296
# Epoch 47/100, Train Loss: 47.1957, Val Loss: 47.0394
# Epoch 48/100, Train Loss: 46.6150, Val Loss: 42.6731
# Epoch 49/100, Train Loss: 45.5429, Val Loss: 46.4950
# Epoch 50/100, Train Loss: 45.5126, Val Loss: 43.4186
# Epoch 51/100, Train Loss: 45.9168, Val Loss: 42.6034
# Epoch 52/100, Train Loss: 44.7146, Val Loss: 41.3513
# Epoch 53/100, Train Loss: 44.3985, Val Loss: 45.1616
# Epoch 54/100, Train Loss: 42.6582, Val Loss: 40.9529
# Epoch 55/100, Train Loss: 43.3664, Val Loss: 44.8231
# Epoch 56/100, Train Loss: 43.2051, Val Loss: 40.2991
# Epoch 57/100, Train Loss: 42.1648, Val Loss: 40.9864
# Epoch 58/100, Train Loss: 42.0377, Val Loss: 43.3398
# Epoch 59/100, Train Loss: 41.7908, Val Loss: 41.7733
# Epoch 60/100, Train Loss: 41.6950, Val Loss: 39.6074
# Epoch 61/100, Train Loss: 42.0191, Val Loss: 39.7391
# Epoch 62/100, Train Loss: 40.2571, Val Loss: 40.3444
# Epoch 63/100, Train Loss: 40.3609, Val Loss: 39.3687
# Epoch 64/100, Train Loss: 39.8796, Val Loss: 39.2476
# Epoch 65/100, Train Loss: 40.3178, Val Loss: 38.0861
# Epoch 66/100, Train Loss: 39.3800, Val Loss: 39.1016
# Epoch 67/100, Train Loss: 38.7065, Val Loss: 39.3977
# Epoch 68/100, Train Loss: 38.5666, Val Loss: 37.5883
# Epoch 69/100, Train Loss: 38.5065, Val Loss: 39.0100
# Epoch 70/100, Train Loss: 38.0893, Val Loss: 37.8133
# Epoch 71/100, Train Loss: 37.6052, Val Loss: 36.7192
# Epoch 72/100, Train Loss: 38.4197, Val Loss: 35.7761
# Epoch 73/100, Train Loss: 37.3878, Val Loss: 35.9733
# Epoch 74/100, Train Loss: 37.2946, Val Loss: 38.4057
# Epoch 75/100, Train Loss: 36.9743, Val Loss: 36.0175
# Epoch 76/100, Train Loss: 37.4881, Val Loss: 35.8334
# Epoch 77/100, Train Loss: 37.4487, Val Loss: 38.3544
# Epoch 78/100, Train Loss: 36.1338, Val Loss: 35.8447
# Epoch 79/100, Train Loss: 35.7243, Val Loss: 37.9483
# Epoch 80/100, Train Loss: 35.7479, Val Loss: 35.4108
# Epoch 81/100, Train Loss: 35.3142, Val Loss: 35.7712
# Epoch 82/100, Train Loss: 35.5354, Val Loss: 36.2867
# Epoch 83/100, Train Loss: 34.5722, Val Loss: 35.3730
# Epoch 84/100, Train Loss: 35.6773, Val Loss: 38.8776
# Epoch 85/100, Train Loss: 34.8115, Val Loss: 34.2554
# Epoch 86/100, Train Loss: 35.1854, Val Loss: 34.4155
# Epoch 87/100, Train Loss: 34.1698, Val Loss: 36.4170
# Epoch 88/100, Train Loss: 34.3066, Val Loss: 34.7648
# Epoch 89/100, Train Loss: 34.2693, Val Loss: 38.9721
# Epoch 90/100, Train Loss: 33.6674, Val Loss: 35.3057
# Epoch 91/100, Train Loss: 33.4061, Val Loss: 35.1709
# Epoch 92/100, Train Loss: 33.5673, Val Loss: 34.2810
# Epoch 93/100, Train Loss: 34.1874, Val Loss: 34.0042
# Epoch 94/100, Train Loss: 35.1907, Val Loss: 35.2423
# Epoch 95/100, Train Loss: 32.8445, Val Loss: 33.6637
# Epoch 96/100, Train Loss: 32.4338, Val Loss: 35.7922
# Epoch 97/100, Train Loss: 32.9988, Val Loss: 33.8620
# Epoch 98/100, Train Loss: 32.9238, Val Loss: 33.0156
# Epoch 99/100, Train Loss: 32.8881, Val Loss: 33.5982
# Epoch 100/100, Train Loss: 32.1031, Val Loss: 35.8926
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_80933/1901634337.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 3 - Val Loss: 33.0156, MAE: 4.1819, RMSE: 5.7369
#
# Fold 4
# Epoch 1/100, Train Loss: 240.1270, Val Loss: 206.9565
# Epoch 2/100, Train Loss: 150.6391, Val Loss: 91.2153
# Epoch 3/100, Train Loss: 87.8868, Val Loss: 79.8240
# Epoch 4/100, Train Loss: 82.9068, Val Loss: 77.6733
# Epoch 5/100, Train Loss: 79.1357, Val Loss: 74.6143
# Epoch 6/100, Train Loss: 75.7776, Val Loss: 69.9183
# Epoch 7/100, Train Loss: 72.8138, Val Loss: 66.5926
# Epoch 8/100, Train Loss: 71.2353, Val Loss: 65.9540
# Epoch 9/100, Train Loss: 70.2132, Val Loss: 66.0484
# Epoch 10/100, Train Loss: 69.0064, Val Loss: 63.9124
# Epoch 11/100, Train Loss: 67.8764, Val Loss: 63.3142
# Epoch 12/100, Train Loss: 67.3152, Val Loss: 63.8738
# Epoch 13/100, Train Loss: 67.3606, Val Loss: 62.0653
# Epoch 14/100, Train Loss: 65.3636, Val Loss: 61.6085
# Epoch 15/100, Train Loss: 65.6345, Val Loss: 63.2202
# Epoch 16/100, Train Loss: 65.1723, Val Loss: 64.2068
# Epoch 17/100, Train Loss: 65.1791, Val Loss: 60.6860
# Epoch 18/100, Train Loss: 63.6719, Val Loss: 61.0333
# Epoch 19/100, Train Loss: 64.2660, Val Loss: 60.5181
# Epoch 20/100, Train Loss: 63.8301, Val Loss: 60.0572
# Epoch 21/100, Train Loss: 63.3589, Val Loss: 58.0848
# Epoch 22/100, Train Loss: 62.7370, Val Loss: 59.6153
# Epoch 23/100, Train Loss: 61.8140, Val Loss: 58.2273
# Epoch 24/100, Train Loss: 61.5220, Val Loss: 58.0648
# Epoch 25/100, Train Loss: 60.5582, Val Loss: 62.1836
# Epoch 26/100, Train Loss: 60.6878, Val Loss: 57.2622
# Epoch 27/100, Train Loss: 59.4531, Val Loss: 60.4311
# Epoch 28/100, Train Loss: 59.8453, Val Loss: 57.5839
# Epoch 29/100, Train Loss: 59.8009, Val Loss: 55.9793
# Epoch 30/100, Train Loss: 58.2085, Val Loss: 55.1127
# Epoch 31/100, Train Loss: 58.7934, Val Loss: 54.2801
# Epoch 32/100, Train Loss: 58.3453, Val Loss: 56.9796
# Epoch 33/100, Train Loss: 57.4741, Val Loss: 57.2543
# Epoch 34/100, Train Loss: 56.2591, Val Loss: 52.8875
# Epoch 35/100, Train Loss: 55.8602, Val Loss: 55.6735
# Epoch 36/100, Train Loss: 55.0582, Val Loss: 53.2197
# Epoch 37/100, Train Loss: 54.7396, Val Loss: 53.0406
# Epoch 38/100, Train Loss: 55.0293, Val Loss: 55.8396
# Epoch 39/100, Train Loss: 53.9216, Val Loss: 51.5609
# Epoch 40/100, Train Loss: 52.6459, Val Loss: 51.4902
# Epoch 41/100, Train Loss: 53.4929, Val Loss: 52.9400
# Epoch 42/100, Train Loss: 52.6032, Val Loss: 51.0040
# Epoch 43/100, Train Loss: 52.3441, Val Loss: 53.9549
# Epoch 44/100, Train Loss: 51.7734, Val Loss: 50.5592
# Epoch 45/100, Train Loss: 51.3231, Val Loss: 51.1904
# Epoch 46/100, Train Loss: 50.4362, Val Loss: 54.5790
# Epoch 47/100, Train Loss: 50.0052, Val Loss: 48.0332
# Epoch 48/100, Train Loss: 49.3488, Val Loss: 47.1530
# Epoch 49/100, Train Loss: 48.6413, Val Loss: 46.8938
# Epoch 50/100, Train Loss: 48.3901, Val Loss: 45.8055
# Epoch 51/100, Train Loss: 48.6810, Val Loss: 46.3300
# Epoch 52/100, Train Loss: 47.5828, Val Loss: 45.2276
# Epoch 53/100, Train Loss: 46.6966, Val Loss: 46.8107
# Epoch 54/100, Train Loss: 46.1069, Val Loss: 45.4202
# Epoch 55/100, Train Loss: 45.6029, Val Loss: 45.7183
# Epoch 56/100, Train Loss: 46.0369, Val Loss: 49.7825
# Epoch 57/100, Train Loss: 45.4948, Val Loss: 42.5610
# Epoch 58/100, Train Loss: 44.2652, Val Loss: 41.1861
# Epoch 59/100, Train Loss: 43.2394, Val Loss: 43.7700
# Epoch 60/100, Train Loss: 43.8714, Val Loss: 43.3581
# Epoch 61/100, Train Loss: 43.2185, Val Loss: 41.5904
# Epoch 62/100, Train Loss: 42.7354, Val Loss: 40.5617
# Epoch 63/100, Train Loss: 41.3263, Val Loss: 42.5109
# Epoch 64/100, Train Loss: 41.9201, Val Loss: 40.7581
# Epoch 65/100, Train Loss: 41.2038, Val Loss: 40.1576
# Epoch 66/100, Train Loss: 41.0813, Val Loss: 41.1885
# Epoch 67/100, Train Loss: 40.5430, Val Loss: 39.1147
# Epoch 68/100, Train Loss: 39.5824, Val Loss: 38.4633
# Epoch 69/100, Train Loss: 41.0539, Val Loss: 38.9842
# Epoch 70/100, Train Loss: 38.9030, Val Loss: 40.4574
# Epoch 71/100, Train Loss: 39.2596, Val Loss: 39.7932
# Epoch 72/100, Train Loss: 38.6118, Val Loss: 38.9566
# Epoch 73/100, Train Loss: 37.9882, Val Loss: 37.4935
# Epoch 74/100, Train Loss: 38.4518, Val Loss: 40.9180
# Epoch 75/100, Train Loss: 37.9242, Val Loss: 37.0067
# Epoch 76/100, Train Loss: 37.7788, Val Loss: 39.8851
# Epoch 77/100, Train Loss: 36.9736, Val Loss: 37.7965
# Epoch 78/100, Train Loss: 36.6142, Val Loss: 38.3002
# Epoch 79/100, Train Loss: 36.5463, Val Loss: 36.9595
# Epoch 80/100, Train Loss: 38.3408, Val Loss: 44.6082
# Epoch 81/100, Train Loss: 37.9219, Val Loss: 36.6602
# Epoch 82/100, Train Loss: 36.8162, Val Loss: 36.4692
# Epoch 83/100, Train Loss: 35.0266, Val Loss: 36.5206
# Epoch 84/100, Train Loss: 35.0350, Val Loss: 36.7395
# Epoch 85/100, Train Loss: 34.8217, Val Loss: 36.6752
# Epoch 86/100, Train Loss: 34.9497, Val Loss: 36.8080
# Epoch 87/100, Train Loss: 34.7303, Val Loss: 37.6061
# Epoch 88/100, Train Loss: 34.3338, Val Loss: 36.3059
# Epoch 89/100, Train Loss: 33.8060, Val Loss: 36.0133
# Epoch 90/100, Train Loss: 33.7638, Val Loss: 35.7139
# Epoch 91/100, Train Loss: 33.3151, Val Loss: 34.8608
# Epoch 92/100, Train Loss: 33.0913, Val Loss: 35.3870
# Epoch 93/100, Train Loss: 33.1175, Val Loss: 36.4740
# Epoch 94/100, Train Loss: 33.6778, Val Loss: 36.9608
# Epoch 95/100, Train Loss: 33.2201, Val Loss: 36.0628
# Epoch 96/100, Train Loss: 32.5389, Val Loss: 36.2079
# Epoch 97/100, Train Loss: 32.5652, Val Loss: 34.7588
# Epoch 98/100, Train Loss: 31.8909, Val Loss: 35.5660
# Epoch 99/100, Train Loss: 32.3278, Val Loss: 34.6724
# Epoch 100/100, Train Loss: 32.5931, Val Loss: 34.8023
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_80933/1901634337.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Fold 4 - Val Loss: 34.6724, MAE: 4.2435, RMSE: 5.8903
#
# Fold 5
# Epoch 1/100, Train Loss: 239.0828, Val Loss: 221.0264
# Epoch 2/100, Train Loss: 147.3910, Val Loss: 123.6823
# Epoch 3/100, Train Loss: 87.4487, Val Loss: 94.4411
# Epoch 4/100, Train Loss: 77.0806, Val Loss: 91.7798
# Epoch 5/100, Train Loss: 73.9128, Val Loss: 87.3770
# Epoch 6/100, Train Loss: 71.5307, Val Loss: 86.2515
# Epoch 7/100, Train Loss: 70.0943, Val Loss: 83.5803
# Epoch 8/100, Train Loss: 68.6795, Val Loss: 85.0383
# Epoch 9/100, Train Loss: 67.8791, Val Loss: 82.6992
# Epoch 10/100, Train Loss: 67.0493, Val Loss: 79.5276
# Epoch 11/100, Train Loss: 65.7123, Val Loss: 79.0777
# Epoch 12/100, Train Loss: 65.4651, Val Loss: 78.5123
# Epoch 13/100, Train Loss: 64.0683, Val Loss: 77.2214
# Epoch 14/100, Train Loss: 63.5791, Val Loss: 76.7285
# Epoch 15/100, Train Loss: 63.4537, Val Loss: 75.7571
# Epoch 16/100, Train Loss: 62.7318, Val Loss: 75.2449
# Epoch 17/100, Train Loss: 62.0938, Val Loss: 75.7592
# Epoch 18/100, Train Loss: 61.2963, Val Loss: 76.5728
# Epoch 19/100, Train Loss: 61.2839, Val Loss: 75.2921
# Epoch 20/100, Train Loss: 61.3839, Val Loss: 74.4144
# Epoch 21/100, Train Loss: 60.2887, Val Loss: 73.8267
# Epoch 22/100, Train Loss: 60.4789, Val Loss: 72.6263
# Epoch 23/100, Train Loss: 60.0932, Val Loss: 72.7090
# Epoch 24/100, Train Loss: 59.5495, Val Loss: 72.7814
# Epoch 25/100, Train Loss: 60.2016, Val Loss: 72.3004
# Epoch 26/100, Train Loss: 59.1442, Val Loss: 72.1235
# Epoch 27/100, Train Loss: 59.4188, Val Loss: 72.6987
# Epoch 28/100, Train Loss: 58.4974, Val Loss: 74.9436
# Epoch 29/100, Train Loss: 58.7145, Val Loss: 72.4561
# Epoch 30/100, Train Loss: 58.0885, Val Loss: 73.2519
# Epoch 31/100, Train Loss: 58.8531, Val Loss: 70.6949
# Epoch 32/100, Train Loss: 58.1890, Val Loss: 72.0492
# Epoch 33/100, Train Loss: 57.8668, Val Loss: 71.6451
# Epoch 34/100, Train Loss: 57.9183, Val Loss: 70.4686
# Epoch 35/100, Train Loss: 57.7718, Val Loss: 71.5985
# Epoch 36/100, Train Loss: 57.2621, Val Loss: 69.9568
# Epoch 37/100, Train Loss: 56.4221, Val Loss: 73.6011
# Epoch 38/100, Train Loss: 56.8283, Val Loss: 69.9034
# Epoch 39/100, Train Loss: 56.1886, Val Loss: 69.8293
# Epoch 40/100, Train Loss: 56.0032, Val Loss: 70.2409
# Epoch 41/100, Train Loss: 56.4542, Val Loss: 69.2126
# Epoch 42/100, Train Loss: 55.8030, Val Loss: 70.4584
# Epoch 43/100, Train Loss: 55.2205, Val Loss: 72.1490
# Epoch 44/100, Train Loss: 54.5851, Val Loss: 69.1087
# Epoch 45/100, Train Loss: 54.7111, Val Loss: 67.2125
# Epoch 46/100, Train Loss: 54.6013, Val Loss: 69.0006
# Epoch 47/100, Train Loss: 54.0403, Val Loss: 68.9749
# Epoch 48/100, Train Loss: 53.4379, Val Loss: 67.5663
# Epoch 49/100, Train Loss: 53.2947, Val Loss: 67.4229
# Epoch 50/100, Train Loss: 52.8124, Val Loss: 67.8404
# Epoch 51/100, Train Loss: 52.3281, Val Loss: 65.9518
# Epoch 52/100, Train Loss: 52.0743, Val Loss: 66.0117
# Epoch 53/100, Train Loss: 51.8377, Val Loss: 66.3268
# Epoch 54/100, Train Loss: 51.3361, Val Loss: 65.1462
# Epoch 55/100, Train Loss: 50.5885, Val Loss: 64.2616
# Epoch 56/100, Train Loss: 50.2704, Val Loss: 65.5954
# Epoch 57/100, Train Loss: 49.8995, Val Loss: 63.4632
# Epoch 58/100, Train Loss: 49.9543, Val Loss: 65.5287
# Epoch 59/100, Train Loss: 49.2075, Val Loss: 62.3416
# Epoch 60/100, Train Loss: 48.9506, Val Loss: 64.1453
# Epoch 61/100, Train Loss: 48.0925, Val Loss: 62.0879
# Epoch 62/100, Train Loss: 48.1286, Val Loss: 60.4588
# Epoch 63/100, Train Loss: 47.4465, Val Loss: 60.9377
# Epoch 64/100, Train Loss: 46.7583, Val Loss: 61.9285
# Epoch 65/100, Train Loss: 46.0462, Val Loss: 63.5755
# Epoch 66/100, Train Loss: 45.6217, Val Loss: 61.4728
# Epoch 67/100, Train Loss: 44.4905, Val Loss: 58.8997
# Epoch 68/100, Train Loss: 44.7410, Val Loss: 60.7472
# Epoch 69/100, Train Loss: 43.8216, Val Loss: 58.9547
# Epoch 70/100, Train Loss: 43.1215, Val Loss: 57.6836
# Epoch 71/100, Train Loss: 43.5629, Val Loss: 56.5571
# Epoch 72/100, Train Loss: 43.6834, Val Loss: 62.4608
# Epoch 73/100, Train Loss: 42.7513, Val Loss: 58.3207
# Epoch 74/100, Train Loss: 42.1181, Val Loss: 57.2193
# Epoch 75/100, Train Loss: 41.4714, Val Loss: 57.4477
# Epoch 76/100, Train Loss: 41.9896, Val Loss: 55.3167
# Epoch 77/100, Train Loss: 40.9270, Val Loss: 62.6288
# Epoch 78/100, Train Loss: 41.4242, Val Loss: 55.1047
# Epoch 79/100, Train Loss: 40.1465, Val Loss: 56.5038
# Epoch 80/100, Train Loss: 40.2576, Val Loss: 56.2978
# Epoch 81/100, Train Loss: 39.6972, Val Loss: 54.2623
# Epoch 82/100, Train Loss: 38.6716, Val Loss: 56.2372
# Epoch 83/100, Train Loss: 39.1540, Val Loss: 53.6434
# Epoch 84/100, Train Loss: 38.4133, Val Loss: 53.8405
# Epoch 85/100, Train Loss: 39.2002, Val Loss: 55.4992
# Epoch 86/100, Train Loss: 37.6531, Val Loss: 54.5774
# Epoch 87/100, Train Loss: 37.6185, Val Loss: 51.2297
# Epoch 88/100, Train Loss: 37.1164, Val Loss: 55.9997
# Epoch 89/100, Train Loss: 37.8155, Val Loss: 51.6674
# Epoch 90/100, Train Loss: 37.1864, Val Loss: 54.0395
# Epoch 91/100, Train Loss: 36.8668, Val Loss: 55.1965
# Epoch 92/100, Train Loss: 36.8635, Val Loss: 53.0252
# Epoch 93/100, Train Loss: 35.9237, Val Loss: 54.4681
# Epoch 94/100, Train Loss: 35.7502, Val Loss: 52.9191
# Epoch 95/100, Train Loss: 35.5509, Val Loss: 53.6777
# Epoch 96/100, Train Loss: 35.9692, Val Loss: 52.2142
# Epoch 97/100, Train Loss: 36.5767, Val Loss: 54.5196
# Early stopping triggered
# /var/folders/bg/rj2597hd4399k2ht0hpblk9r0000gn/T/ipykernel_80933/1901634337.py:165: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pth'))
# Fold 5 - Val Loss: 51.2297, MAE: 4.6840, RMSE: 7.1552
#
# Average Val Loss: 37.5061
# Average MAE: 4.2920
# Average RMSE: 6.0954
# /Users/lvsuyi/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
